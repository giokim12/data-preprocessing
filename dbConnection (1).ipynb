# %%
import time
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import configparser
from datetime import datetime

# %% [markdown]
# # 0. sql 연결 Engine 설정

# %%
engine = create_engine("mysql+pymysql://root:"+"returnz_c106!"+"@j8c106.p.ssafy.io:3306/test_db?charset=utf8")

# %%
# 연결 확인
conn = engine.connect()

# %% [markdown]
# # 1. valid_company_list 삽입

# %%
valid_company_list = pd.read_csv("C:/Users/SSAFY/Desktop/S08P22C106/bigData/data/valid_company_list.csv")
valid_company_list
# Out:
#            code                                       company_name
# 0     095570.KS                                          AJ네트웍스보통주
# 1     006840.KS                                           AK홀딩스보통주
# 2     282330.KS                                          BGF리테일보통주
# 3     027410.KS                                             BGF보통주
# 4     138930.KS                                         BNK금융지주보통주
# ...         ...                                                ...
# 1150        XEL                      Xcel Energy Inc. Common Stock
# 1151         XM  Qualtrics International Inc. Class A Common Stock
# 1152       ZBRA  Zebra Technologies Corporation Class A Common ...
# 1153         ZM  Zoom Video Communications Inc. Class A Common ...
# 1154         ZS                          Zscaler Inc. Common Stock
#
# [1155 rows x 2 columns]

# %%
# name = 테이블 이름 , con = 연결할 엔진, if_exists='append' : 존재하면 추가
valid_company_list.to_sql(name="comapny", con=engine, if_exists='append', index=False)

# %% [markdown]
# # 2. one_day_price 파일 저장

# %%
one_day_price = pd.read_csv("C:/Users/SSAFY/Desktop/S08P22C106/bigData/data/one_day_price.csv")

# %%
one_day_price.columns = ["date_time", "open", "high", "low", "close", "volume", "adjclose", "dividends", "splits", "company_code"]
one_day_price
# Out:
#           date_time         open         high          low        close  \
# 0        2015-08-21  6180.000000  7300.000000  5600.000000  7100.000000
# 1        2015-08-24  6700.000000  6940.000000  6240.000000  6480.000000
# 2        2015-08-25  6610.000000  6730.000000  6190.000000  6220.000000
# 3        2015-08-26  6260.000000  7760.000000  6260.000000  7090.000000
# 4        2015-08-27  7240.000000  8060.000000  6960.000000  7570.000000
# ...             ...          ...          ...          ...          ...
# 5190321  2023-03-13   105.550003   111.510002   103.540001   109.860001
# 5190322  2023-03-14   111.519997   111.750000   107.000000   107.970001
# 5190323  2023-03-15   107.220001   108.250000   105.139999   107.669998
# 5190324  2023-03-16   106.349998   108.589996   105.330002   108.129997
# 5190325  2023-03-17   107.769997   108.279999   104.241997   105.489998
#
#             volume     adjclose  dividends  splits company_code
# ...

# %%
one_day_price = one_day_price.drop(columns= ["splits"])
one_day_price
# Out:
#           date_time         open         high          low        close  \
# 0        2015-08-21  6180.000000  7300.000000  5600.000000  7100.000000
# 1        2015-08-24  6700.000000  6940.000000  6240.000000  6480.000000
# 2        2015-08-25  6610.000000  6730.000000  6190.000000  6220.000000
# 3        2015-08-26  6260.000000  7760.000000  6260.000000  7090.000000
# 4        2015-08-27  7240.000000  8060.000000  6960.000000  7570.000000
# ...             ...          ...          ...          ...          ...
# 5190321  2023-03-13   105.550003   111.510002   103.540001   109.860001
# 5190322  2023-03-14   111.519997   111.750000   107.000000   107.970001
# 5190323  2023-03-15   107.220001   108.250000   105.139999   107.669998
# 5190324  2023-03-16   106.349998   108.589996   105.330002   108.129997
# 5190325  2023-03-17   107.769997   108.279999   104.241997   105.489998
#
#             volume     adjclose  dividends company_code
# ...

# %%
one_day_price.to_sql(name="historical_price_day", con=engine, if_exists='append', index=False)
# Out:
# 5190326

# %% [markdown]
# # 3. one_hour_price

# %% [markdown]
# # 4. one_minute_price

# %%
one_minute_price = pd.read_csv("C:/Users/SSAFY/Desktop/S08P22C106/bigData/data/one_minute_price.csv")
one_minute_price
# Out:
#          Unnamed: 0                       date         open         high  \
# 0                 0  2023-03-15 11:01:00+09:00  4980.000000  4985.000000
# 1                 1  2023-03-15 11:02:00+09:00  4980.000000  4985.000000
# 2                 2  2023-03-15 11:03:00+09:00  4985.000000  4985.000000
# 3                 3  2023-03-15 11:04:00+09:00  4980.000000  4990.000000
# 4                 4  2023-03-15 11:05:00+09:00  4990.000000  4990.000000
# ...             ...                        ...          ...          ...
# 5674064     1539819  2023-02-28 15:56:00-05:00   131.179993   131.289993
# 5674065     1539820  2023-02-28 15:57:00-05:00   131.279999   131.279999
# 5674066     1539821  2023-02-28 15:58:00-05:00   131.210007   131.210007
# 5674067     1539822  2023-02-28 15:59:00-05:00   131.160004   131.169998
# 5674068     1539823  2023-03-21 16:00:00-04:00   113.019997   113.019997
#
#                  low        close   volume     symbol  splits  adjclose  \
# ...

# %%
def transform_datetype(df):
    df['date'] = df['date'].astype('str')
    df['date'] = pd.to_datetime(df['date'])
    return df

# one_minute_price = transform_datetype(one_minute_price)
one_minute_price['date'] = one_minute_price['date'].apply(lambda x: pd.to_datetime(str(x), format='%Y-%m-%d %H:%M:%S'))
one_minute_price
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python311\Lib\zoneinfo\_common.py:12, in load_tzdata(key)
#       9 resource_name = components[-1]
#      11 try:
# ---> 12     return resources.files(package_name).joinpath(resource_name).open("rb")
#      13 except (ImportError, FileNotFoundError, UnicodeEncodeError):
#      14     # There are three types of exception that can be raised that all amount
#      15     # to "we cannot find this key":
#    (...)
#      22     # UnicodeEncodeError: If package_name or resource_name are not UTF-8,
#      23     #   such as keys containing a surrogate character.
#      24     raise ZoneInfoNotFoundError(f"No time zone found with key {key}")
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python311\Lib\importlib\resources\_common.py:22, in files(package)
# ...

# %%
one_minute_price = one_minute_price.drop(columns=['Unnamed: 0', 'splits', "adjclose", "dividends"])
one_minute_price.columns = ["date_time", "open", "high", "low", "close", "volume", "company_code"]
one_minute_price
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 one_minute_price = one_minute_price.drop(columns=['Unnamed: 0', 'splits', "adjclose", "dividends"])
# ----> 2 one_minute_price['date'].apply(lambda _ : datetime.strptime(_,'%Y%m%d %H:%M:%S'))
#       3 one_minute_price.columns = ["date_time", "open", "high", "low", "close", "volume", "company_code"]
#       4 one_minute_price
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# ...

# %%
one_minute_price.to_sql(name="historical_price_minute", con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1933, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1932     if not evt_handled:
# -> 1933         self.dialect.do_executemany(
#    1934             cursor,
#    1935             str_statement,
#    1936             effective_parameters,
#    1937             context,
#    1938         )
#    1939 elif not effective_parameters and context.no_parameters:
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:175, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     174 def do_executemany(self, cursor, statement, parameters, context=None):
# ...

# %% [markdown]
# # 5. Grading History

# %%
grading_history = pd.read_csv("C:/Users/SSAFY/Desktop/S08P22C106/bigData/data/grading_history.csv")
grading_history.to_csv("C:/Users/SSAFY/Desktop/S08P22C106/bigData/data/grading_history.csv", sep=',', index=False, encoding='utf-8')

# %%
grading_history = pd.read_csv("C:/Users/SSAFY/Desktop/S08P22C106/bigData/data/grading_history.csv")
grading_history.rename(columns={"code":"company_code", "epochGradeDate":"epoch_grade_date", "toGrade":"to_grade", "fromGrade":"from_grade"}, inplace=True)
grading_history = grading_history.drop(columns=["row"])
grading_history
# Out:
#       company_code  epoch_grade_date                firm      to_grade  \
# 0             AAPL  2023-03-10 22:09  LightShed Partners          Sell
# 1             AAPL  2023-03-10 20:54             Needham           Buy
# 2             AAPL  2023-03-08 22:38             Wedbush    Outperform
# 3             AAPL  2023-03-06 19:05       Goldman Sachs           Buy
# 4             AAPL  2023-03-02 23:17           Jefferies           Buy
# ...            ...               ...                 ...           ...
# 39923           ZS   2018-04-11 4:54      Morgan Stanley  Equal-Weight
# 39924           ZS   2018-04-11 4:51       Credit Suisse    Outperform
# 39925           ZS   2018-04-11 4:51       Deutsche Bank          Hold
# 39926           ZS   2018-04-11 4:43       Goldman Sachs       Neutral
# 39927           ZS  2018-04-10 21:33       BTIG Research           Buy
#
#       from_grade action
# 0        Neutral   down
# 1            NaN   reit
# 2            NaN   main
# ...

# %%
grading_history.to_sql(name="grading_history", con=engine, if_exists='append', index=False)
# Out:
# 39928

# %% [markdown]
# # 6. Corporate Events

# %% [markdown]
# # 7. asset_profile

# %%
asset_profile = pd.read_csv("C:/Users/SSAFY/Desktop/S08P22C106/bigData/data/asset_profile.csv", encoding="cp949")
asset_profile.to_csv("C:/Users/SSAFY/Desktop/S08P22C106/bigData/data/asset_profile.csv", sep=',', index=False, encoding='utf-8')

# %%
asset_profile = pd.read_csv("C:/Users/SSAFY/Desktop/S08P22C106/bigData/data/asset_profile.csv")
asset_profile
# Out:
#            code country_code       ko_name  \
# 0     095570.KS           KR        AJ네트웍스
# 1     006840.KS           KR         AK홀딩스
# 2     027410.KS           KR           BGF
# 3     282330.KS           KR        BGF리테일
# 4     138930.KS           KR       BNK금융지주
# ...         ...          ...           ...
# 1153        XEL           US        엑셀 에너지
# 1154         XM           US    퀄트릭스 인터내셔널
# 1155       ZBRA           US    지브라 테크놀로지스
# 1156         ZM           US  줌 비디오 커뮤니케이션
# 1157         ZS           US         지스케일러
#
#                                             description  sector   industry  \
# 0     AJ네트웍스는 2000년 2월 설립된 기업으로 파렛트, IT기기, 건설장비 등의 렌...      운송     육상여객운송
# 1     AK홀딩스는 1970년 설립된 기업으로 애경 그룹 지주회사이다. 주요 종속기업은 에...      기타  지주회사/복합기업
# 2     BGF는 2017년 11월 (주)비지에프리테일에서 인적분할되어 설립되었으며 투자사업...      기타  지주회사/복합기업
# 3     BGF리테일은 2017년 11월 (주)비지에프에서 분할 설립된 기업으로 편의점 체인...      소매   편의점/대형마트
# ...

# %%
asset_profile.rename(columns={"code":"company_code"}, inplace=True)
asset_profile
# Out:
#      company_code country_code       ko_name  \
# 0       095570.KS           KR        AJ네트웍스
# 1       006840.KS           KR         AK홀딩스
# 2       027410.KS           KR           BGF
# 3       282330.KS           KR        BGF리테일
# 4       138930.KS           KR       BNK금융지주
# ...           ...          ...           ...
# 1153          XEL           US        엑셀 에너지
# 1154           XM           US    퀄트릭스 인터내셔널
# 1155         ZBRA           US    지브라 테크놀로지스
# 1156           ZM           US  줌 비디오 커뮤니케이션
# 1157           ZS           US         지스케일러
#
#                                             description  sector   industry  \
# 0     AJ네트웍스는 2000년 2월 설립된 기업으로 파렛트, IT기기, 건설장비 등의 렌...      운송     육상여객운송
# 1     AK홀딩스는 1970년 설립된 기업으로 애경 그룹 지주회사이다. 주요 종속기업은 에...      기타  지주회사/복합기업
# 2     BGF는 2017년 11월 (주)비지에프리테일에서 인적분할되어 설립되었으며 투자사업...      기타  지주회사/복합기업
# 3     BGF리테일은 2017년 11월 (주)비지에프에서 분할 설립된 기업으로 편의점 체인...      소매   편의점/대형마트
# ...

# %%
for a in list(asset_profile["company_code"]):
    if a not in list(valid_company_list["code"]):
        print(a)

asset_profile.drop(asset_profile[asset_profile["company_code"].str.contains("00279K.KS")].index, inplace=True)
asset_profile.drop(asset_profile[asset_profile["company_code"].str.contains("45014K.KS")].index, inplace=True)
asset_profile.drop(asset_profile[asset_profile["company_code"].str.contains("152550.KS")].index, inplace=True)

# %%
asset_profile.to_sql(name="company_detail", con=engine, if_exists='append', index=False)
# Out:
# 1155

# %% [markdown]
# # 8. recommendations

# %%
recommendations = pd.read_csv("C:/Users/SSAFY/Desktop/S08P22C106/bigData/data/recommendations.csv", encoding="cp949")
recommendations.to_csv("C:/Users/SSAFY/Desktop/S08P22C106/bigData/data/recommendations.csv", sep=',', index=False, encoding='utf-8')
recommendations
# Out:
#       Unnamed: 0       code simillar_company_code     score
# 0              0  095570.KS             071050.KS  0.002166
# 1              1  095570.KS             005950.KS  0.002144
# 2              2  095570.KS                8424.T  0.001952
# 3              3  095570.KS             093050.KS  0.001933
# 4              4  095570.KS             097230.KS  0.001914
# ...          ...        ...                   ...       ...
# 5700        5700         ZS                  CRWD  0.203784
# 5701        5701         ZS                  OKTA  0.202393
# 5702        5702         ZS                  DDOG  0.175393
# 5703        5703         ZS                   NET  0.157310
# 5704        5704         ZS                   TTD  0.147948
#
# [5705 rows x 4 columns]

# %%
recommendations = recommendations.drop(columns=["Unnamed: 0"])
recommendations.rename(columns={"code":"company_code"}, inplace=True)

# %%
recommendations.to_sql(name="recommended_company", con=engine, if_exists='append', index=False)
# Out:
# 5705
