# %%
import pandas as pd
import datetime
import yfinance as yf

# %%
# company_list = ["AAPL", "GOOG", "CSCO", "MSFT"]
tick = 'USDKRW=X'
end = datetime.datetime.now()
start = '1997-01-01'

# %%
change = yf.download(tick, start=start, end=end)
change
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2003-12-01  1197.300049  1203.500000  1195.000000  1198.400024  1198.400024
# 2003-12-02  1198.099976  1198.500000  1186.199951  1195.000000  1195.000000
# 2003-12-03  1195.000000  1198.400024  1192.500000  1192.500000  1192.500000
# 2003-12-04  1192.599976  1197.900024  1174.800049  1190.099976  1190.099976
# 2003-12-05  1189.400024  1193.800049  1178.599976  1184.699951  1184.699951
# ...                 ...          ...          ...          ...          ...
# 2019-12-25  1161.300049  1162.229980  1159.739990  1162.229980  1162.229980
# 2019-12-26  1159.750000  1163.650024  1159.150024  1159.750000  1159.750000
# 2019-12-27  1160.109985  1161.890015  1156.390015  1161.199951  1161.199951
# 2019-12-30  1158.709961  1159.489990  1153.910034  1160.680054  1160.680054
# ...

# %%
origin_data
# Out:
#                             Adj Close                                    \
#                                  AAPL       CSCO       GOOG        MSFT
# Datetime
# 2023-02-23 14:08:00-05:00  148.380005  48.834999  90.714996  252.179993
# 2023-02-23 14:09:00-05:00  148.350006  48.825001  90.750000  252.130005
# 2023-02-23 14:10:00-05:00  148.360199  48.810001  90.739998  252.210007
# 2023-02-23 14:11:00-05:00  148.449997  48.830002  90.764999  252.324997
# 2023-02-23 14:12:00-05:00  148.537506  48.830002  90.794998  252.350006
# ...                               ...        ...        ...         ...
# 2023-03-01 15:55:00-05:00  145.205002  48.355000  90.489998  245.839996
# 2023-03-01 15:56:00-05:00  145.250000  48.375000  90.470001  246.300003
# 2023-03-01 15:57:00-05:00  145.274994  48.340000  90.525398  246.339996
# 2023-03-01 15:58:00-05:00  145.244995  48.340000  90.555000  246.360001
# 2023-03-01 15:59:00-05:00  145.320007  48.349998  90.550003  246.240005
#
# ...

# %%
company_datas (dict)  
key : company code ( ex) "AAPL" )  
value : Company DataFrame data  

# Multi index DataFrame slicing
data_columns = set(list(map(lambda x: ' '.join(x[:1]),origin_data.columns)))
print(data_columns)

# 각 회사 코드를 key로 DataFrame을 value로 하는 dict 생성
company_datas = dict()
for company in company_list:
  tmp_df = pd.DataFrame()
  for column in data_columns:
    tmp_df[column] = origin_data[column, company]
  company_datas[company] = tmp_df

company_datas

# %%
Tickers = dict()
for company in company_list:
    Tickers[company] = (yf.Ticker(company))
    print(company, "배당 내역")
    print(Tickers[company].dividends)
    print(company, "주식 분할 내역")
    print(Tickers[company].splits)
# Out:
# AAPL 배당 내역
# Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2022-02-04 00:00:00-05:00    0.220000
# 2022-05-06 00:00:00-04:00    0.230000
# 2022-08-05 00:00:00-04:00    0.230000
# 2022-11-04 00:00:00-04:00    0.230000
# 2023-02-10 00:00:00-05:00    0.230000
# Name: Dividends, Length: 78, dtype: float64
# AAPL 주식 분할 내역
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64
# GOOG 배당 내역
# Series([], Name: Dividends, dtype: float64)
# GOOG 주식 분할 내역
# Date
# 2014-03-27 00:00:00-04:00     2.002000
# 2015-04-27 00:00:00-04:00     1.002746
# 2022-07-18 00:00:00-04:00    20.000000
# Name: Stock Splits, dtype: float64
# CSCO 배당 내역
# Date
# ...

# %%
# Out:
# {}
