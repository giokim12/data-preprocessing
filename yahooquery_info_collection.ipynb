# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime
import yahooquery as yq
from yahooquery import Ticker

aapl = Ticker('aapl')

aapl.summary_detail
# Out:
# {'aapl': {'maxAge': 1,
#   'priceHint': 2,
#   'previousClose': 152.99,
#   'open': 152.16,
#   'dayLow': 151.64,
#   'dayHigh': 156.42,
#   'regularMarketPreviousClose': 152.99,
#   'regularMarketOpen': 152.16,
#   'regularMarketDayLow': 151.64,
#   'regularMarketDayHigh': 156.42,
#   'dividendRate': 0.92,
#   'dividendYield': 0.006,
#   'exDividendDate': '2023-02-10 09:00:00',
#   'payoutRatio': 0.1545,
#   'fiveYearAvgDividendYield': 0.95,
#   'beta': 1.297088,
#   'trailingPE': 26.37056,
#   'forwardPE': 23.577913,
#   'volume': 76254419,
#   'regularMarketVolume': 76254419,
#   'averageVolume': 70672291,
#   'averageVolume10days': 67153030,
#   'averageDailyVolume10Day': 67153030,
#   'bid': 155.81,
#   'ask': 155.85,
#   'bidSize': 3000,
#   'askSize': 800,
#   'marketCap': 2465843118080,
#   'fiftyTwoWeekLow': 124.17,
#   'fiftyTwoWeekHigh': 179.61,
#   'priceToSalesTrailing12Months': 6.3628583,
#   'fiftyDayAverage': 144.7934,
#   'twoHundredDayAverage': 147.61075,
#   'trailingAnnualDividendRate': 0.91,
#   'trailingAnnualDividendYield': 0.005948101,
#   'currency': 'USD',
#   'fromCurrency': None,
#   'toCurrency': None,
#   'lastMarket': None,
#   'coinMarketCapLink': None,
#   'algorithm': None,
#   'tradeable': False}}

# %%
yq.get_currencies()
# Out:
# [{'shortName': 'FJD',
#   'longName': 'Fijian Dollar',
#   'symbol': 'FJD',
#   'localLongName': 'Fijian Dollar'},
#  {'shortName': 'MXN',
#   'longName': 'Mexican Peso',
#   'symbol': 'MXN',
#   'localLongName': 'Mexican Peso'},
#  {'shortName': 'LVL',
#   'longName': 'Latvian Lats',
#   'symbol': 'LVL',
#   'localLongName': 'Latvian Lats'},
#  {'shortName': 'SCR',
#   'longName': 'Seychellois Rupee',
#   'symbol': 'SCR',
#   'localLongName': 'Seychellois Rupee'},
#  {'shortName': 'CDF',
#   'longName': 'Congolese Franc',
#   'symbol': 'CDF',
#   'localLongName': 'Congolese Franc'},
#  {'shortName': 'BBD',
#   'longName': 'Barbadian Dollar',
#   'symbol': 'BBD',
#   'localLongName': 'Barbadian Dollar'},
#  {'shortName': 'GTQ',
#   'longName': 'Guatemalan Quetzal',
#   'symbol': 'GTQ',
#   'localLongName': 'Guatemalan Quetzal'},
#  {'shortName': 'CLP',
#   'longName': 'Chilean Peso',
#   'symbol': 'CLP',
#   'localLongName': 'Chilean Peso'},
#  {'shortName': 'HNL',
#   'longName': 'Honduran Lempira',
#   'symbol': 'HNL',
#   'localLongName': 'Honduran Lempira'},
#  {'shortName': 'UGX',
#   'longName': 'Ugandan Shilling',
#   'symbol': 'UGX',
#   'localLongName': 'Ugandan Shilling'},
#  {'shortName': 'MXV',
#   'longName': 'Mexican Investment Unit',
#   'symbol': 'MXV',
#   'localLongName': 'Mexican Investment Unit'},
#  {'shortName': 'ZAR',
#   'longName': 'South African Rand',
#   'symbol': 'ZAR',
#   'localLongName': 'South African Rand'},
#  {'shortName': 'TND',
#   'longName': 'Tunisian Dinar',
#   'symbol': 'TND',
#   'localLongName': 'Tunisian Dinar'},
#  {'shortName': 'STN',
#   'longName': 'São Tomé and Príncipe Dobra',
#   'symbol': 'STN',
#   'localLongName': 'São Tomé and Príncipe Dobra'},
#  {'shortName': 'CUC',
#   'longName': 'Cuban Convertible Peso',
#   'symbol': 'CUC',
#   'localLongName': 'Cuban Convertible Peso'},
#  {'shortName': 'BSD',
#   'longName': 'Bahamian Dollar',
#   'symbol': 'BSD',
#   'localLongName': 'Bahamian Dollar'},
#  {'shortName': 'SLL',
#   'longName': 'Sierra Leonean Leone',
#   'symbol': 'SLL',
#   'localLongName': 'Sierra Leonean Leone'},
#  {'shortName': 'SDG',
#   'longName': 'Sudanese Pound',
#   'symbol': 'SDG',
#   'localLongName': 'Sudanese Pound'},
#  {'shortName': 'IQD',
#   'longName': 'Iraqi Dinar',
#   'symbol': 'IQD',
#   'localLongName': 'Iraqi Dinar'},
#  {'shortName': 'GMD',
#   'longName': 'Gambian Dalasi',
#   'symbol': 'GMD',
#   'localLongName': 'Gambian Dalasi'},
#  {'shortName': 'CUP',
#   'longName': 'Cuban Peso',
#   'symbol': 'CUP',
#   'localLongName': 'Cuban Peso'},
#  {'shortName': 'TWD',
#   'longName': 'New Taiwan Dollar',
#   'symbol': 'TWD',
#   'localLongName': 'New Taiwan Dollar'},
#  {'shortName': 'RSD',
#   'longName': 'Serbian Dinar',
#   'symbol': 'RSD',
#   'localLongName': 'Serbian Dinar'},
#  {'shortName': 'DOP',
#   'longName': 'Dominican Peso',
#   'symbol': 'DOP',
#   'localLongName': 'Dominican Peso'},
#  {'shortName': 'KMF',
#   'longName': 'Comorian Franc',
#   'symbol': 'KMF',
#   'localLongName': 'Comorian Franc'},
#  {'shortName': 'MYR',
#   'longName': 'Malaysian Ringgit',
#   'symbol': 'MYR',
#   'localLongName': 'Malaysian Ringgit'},
#  {'shortName': 'FKP',
#   'longName': 'Falkland Islands Pound',
#   'symbol': 'FKP',
#   'localLongName': 'Falkland Islands Pound'},
#  {'shortName': 'XOF',
#   'longName': 'CFA Franc BCEAO',
#   'symbol': 'XOF',
#   'localLongName': 'CFA Franc BCEAO'},
#  {'shortName': 'GEL',
#   'longName': 'Georgian Lari',
#   'symbol': 'GEL',
#   'localLongName': 'Georgian Lari'},
#  {'shortName': 'UYU',
#   'longName': 'Uruguayan Peso',
#   'symbol': 'UYU',
#   'localLongName': 'Uruguayan Peso'},
#  {'shortName': 'MAD',
#   'longName': 'Moroccan Dirham',
#   'symbol': 'MAD',
#   'localLongName': 'Moroccan Dirham'},
#  {'shortName': 'CVE',
#   'longName': 'Cape Verdean Escudo',
#   'symbol': 'CVE',
#   'localLongName': 'Cape Verdean Escudo'},
#  {'shortName': 'TOP',
#   'longName': 'Tongan Paʻanga',
#   'symbol': 'TOP',
#   'localLongName': 'Tongan Paʻanga'},
#  {'shortName': 'OMR',
#   'longName': 'Omani Rial',
#   'symbol': 'OMR',
#   'localLongName': 'Omani Rial'},
#  {'shortName': 'AZN',
#   'longName': 'Azerbaijan Manat',
#   'symbol': 'AZN',
#   'localLongName': 'Azerbaijan Manat'},
#  {'shortName': 'PGK',
#   'longName': 'Papua New Guinean Kina',
#   'symbol': 'PGK',
#   'localLongName': 'Papua New Guinean Kina'},
#  {'shortName': 'KES',
#   'longName': 'Kenyan Shilling',
#   'symbol': 'KES',
#   'localLongName': 'Kenyan Shilling'},
#  {'shortName': 'SEK',
#   'longName': 'Swedish Krona',
#   'symbol': 'SEK',
#   'localLongName': 'Swedish Krona'},
#  {'shortName': 'BTN',
#   'longName': 'Bhutanese Ngultrum',
#   'symbol': 'BTN',
#   'localLongName': 'Bhutanese Ngultrum'},
#  {'shortName': 'UAH',
#   'longName': 'Ukrainian Hryvnia',
#   'symbol': 'UAH',
#   'localLongName': 'Ukrainian Hryvnia'},
#  {'shortName': 'GNF',
#   'longName': 'Guinean Franc',
#   'symbol': 'GNF',
#   'localLongName': 'Guinean Franc'},
#  {'shortName': 'MZN',
#   'longName': 'Mozambican Metical',
#   'symbol': 'MZN',
#   'localLongName': 'Mozambican Metical'},
#  {'shortName': 'ERN',
#   'longName': 'Eritrean Nakfa',
#   'symbol': 'ERN',
#   'localLongName': 'Eritrean Nakfa'},
#  {'shortName': 'SVC',
#   'longName': 'Salvadoran Colón',
#   'symbol': 'SVC',
#   'localLongName': 'Salvadoran Colón'},
#  {'shortName': 'ARS',
#   'longName': 'Argentine Peso',
#   'symbol': 'ARS',
#   'localLongName': 'Argentine Peso'},
#  {'shortName': 'QAR',
#   'longName': 'Qatari Rial',
#   'symbol': 'QAR',
#   'localLongName': 'Qatari Rial'},
#  {'shortName': 'IRR',
#   'longName': 'Iranian Rial',
#   'symbol': 'IRR',
#   'localLongName': 'Iranian Rial'},
#  {'shortName': 'XPD',
#   'longName': 'Palladium',
#   'symbol': 'XPD',
#   'localLongName': 'Palladium'},
#  {'shortName': 'XPF',
#   'longName': 'CFP Franc',
#   'symbol': 'XPF',
#   'localLongName': 'CFP Franc'},
#  {'shortName': 'UZS',
#   'longName': 'Uzbekistan Som',
#   'symbol': 'UZS',
#   'localLongName': 'Uzbekistan Som'},
#  {'shortName': 'CNY',
#   'longName': 'Chinese Yuan',
#   'symbol': 'CNY',
#   'localLongName': 'Chinese Yuan'},
#  {'shortName': 'THB',
#   'longName': 'Thai Baht',
#   'symbol': 'THB',
#   'localLongName': 'Thai Baht'},
#  {'shortName': 'MRU',
#   'longName': 'Mauritanian Ouguiya',
#   'symbol': 'MRU',
#   'localLongName': 'Mauritanian Ouguiya'},
#  {'shortName': 'BDT',
#   'longName': 'Bangladeshi Taka',
#   'symbol': 'BDT',
#   'localLongName': 'Bangladeshi Taka'},
#  {'shortName': 'LYD',
#   'longName': 'Libyan Dinar',
#   'symbol': 'LYD',
#   'localLongName': 'Libyan Dinar'},
#  {'shortName': 'BMD',
#   'longName': 'Bermudan Dollar',
#   'symbol': 'BMD',
#   'localLongName': 'Bermudan Dollar'},
#  {'shortName': 'KWD',
#   'longName': 'Kuwaiti Dinar',
#   'symbol': 'KWD',
#   'localLongName': 'Kuwaiti Dinar'},
#  {'shortName': 'PHP',
#   'longName': 'Philippine Peso',
#   'symbol': 'PHP',
#   'localLongName': 'Philippine Peso'},
#  {'shortName': 'XPT',
#   'longName': 'Platinum',
#   'symbol': 'XPT',
#   'localLongName': 'Platinum'},
#  {'shortName': 'RUB',
#   'longName': 'Russian Ruble',
#   'symbol': 'RUB',
#   'localLongName': 'Russian Ruble'},
#  {'shortName': 'PYG',
#   'longName': 'Paraguayan Guarani',
#   'symbol': 'PYG',
#   'localLongName': 'Paraguayan Guarani'},
#  {'shortName': 'JMD',
#   'longName': 'Jamaican Dollar',
#   'symbol': 'JMD',
#   'localLongName': 'Jamaican Dollar'},
#  {'shortName': 'ISK',
#   'longName': 'Icelandic Króna',
#   'symbol': 'ISK',
#   'localLongName': 'Icelandic Króna'},
#  {'shortName': 'COP',
#   'longName': 'Colombian Peso',
#   'symbol': 'COP',
#   'localLongName': 'Colombian Peso'},
#  {'shortName': 'USD',
#   'longName': 'US Dollar',
#   'symbol': 'USD',
#   'localLongName': 'US Dollar'},
#  {'shortName': 'MKD',
#   'longName': 'Macedonian Denar',
#   'symbol': 'MKD',
#   'localLongName': 'Macedonian Denar'},
#  {'shortName': 'DZD',
#   'longName': 'Algerian Dinar',
#   'symbol': 'DZD',
#   'localLongName': 'Algerian Dinar'},
#  {'shortName': 'PAB',
#   'longName': 'Panamanian Balboa',
#   'symbol': 'PAB',
#   'localLongName': 'Panamanian Balboa'},
#  {'shortName': 'SGD',
#   'longName': 'Singapore Dollar',
#   'symbol': 'SGD',
#   'localLongName': 'Singapore Dollar'},
#  {'shortName': 'ETB',
#   'longName': 'Ethiopian Birr',
#   'symbol': 'ETB',
#   'localLongName': 'Ethiopian Birr'},
#  {'shortName': 'SOS',
#   'longName': 'Somali Shilling',
#   'symbol': 'SOS',
#   'localLongName': 'Somali Shilling'},
#  {'shortName': 'VUV',
#   'longName': 'Vanuatu Vatu',
#   'symbol': 'VUV',
#   'localLongName': 'Vanuatu Vatu'},
#  {'shortName': 'KGS',
#   'longName': 'Kyrgystani Som',
#   'symbol': 'KGS',
#   'localLongName': 'Kyrgystani Som'},
#  {'shortName': 'LAK',
#   'longName': 'Lao Kip',
#   'symbol': 'LAK',
#   'localLongName': 'Lao Kip'},
#  {'shortName': 'BND',
#   'longName': 'Brunei Dollar',
#   'symbol': 'BND',
#   'localLongName': 'Brunei Dollar'},
#  {'shortName': 'XAF',
#   'longName': 'CFA Franc BEAC',
#   'symbol': 'XAF',
#   'localLongName': 'CFA Franc BEAC'},
#  {'shortName': 'XAG',
#   'longName': 'Silver',
#   'symbol': 'XAG',
#   'localLongName': 'Silver'},
#  {'shortName': 'LRD',
#   'longName': 'Liberian Dollar',
#   'symbol': 'LRD',
#   'localLongName': 'Liberian Dollar'},
#  {'shortName': 'HRK',
#   'longName': 'Kuna',
#   'symbol': 'HRK',
#   'localLongName': 'Kuna'},
#  {'shortName': 'CHF',
#   'longName': 'Swiss Franc',
#   'symbol': 'CHF',
#   'localLongName': 'Swiss Franc'},
#  {'shortName': 'DJF',
#   'longName': 'Djiboutian Franc',
#   'symbol': 'DJF',
#   'localLongName': 'Djiboutian Franc'},
#  {'shortName': 'ALL',
#   'longName': 'Albanian Lek',
#   'symbol': 'ALL',
#   'localLongName': 'Albanian Lek'},
#  {'shortName': 'ZMW',
#   'longName': 'ZMW',
#   'symbol': 'ZMW',
#   'localLongName': 'ZMW'},
#  {'shortName': 'VES',
#   'longName': 'Venezuelan Bolívar Soberano',
#   'symbol': 'VES',
#   'localLongName': 'Venezuelan Bolívar Soberano'},
#  {'shortName': 'TZS',
#   'longName': 'Tanzanian Shilling',
#   'symbol': 'TZS',
#   'localLongName': 'Tanzanian Shilling'},
#  {'shortName': 'VND',
#   'longName': 'Vietnamese Dong',
#   'symbol': 'VND',
#   'localLongName': 'Vietnamese Dong'},
#  {'shortName': 'XAU',
#   'longName': 'Gold',
#   'symbol': 'XAU',
#   'localLongName': 'Gold'},
#  {'shortName': 'AUD',
#   'longName': 'Australian Dollar',
#   'symbol': 'AUD',
#   'localLongName': 'Australian Dollar'},
#  {'shortName': 'ILS',
#   'longName': 'Israeli New Sheqel',
#   'symbol': 'ILS',
#   'localLongName': 'Israeli New Sheqel'},
#  {'shortName': 'GYD',
#   'longName': 'Guyanaese Dollar',
#   'symbol': 'GYD',
#   'localLongName': 'Guyanaese Dollar'},
#  {'shortName': 'KPW',
#   'longName': 'North Korean Won',
#   'symbol': 'KPW',
#   'localLongName': 'North Korean Won'},
#  {'shortName': 'GHS',
#   'longName': 'Ghanaian Cedi',
#   'symbol': 'GHS',
#   'localLongName': 'Ghanaian Cedi'},
#  {'shortName': 'KHR',
#   'longName': 'Cambodian Riel',
#   'symbol': 'KHR',
#   'localLongName': 'Cambodian Riel'},
#  {'shortName': 'BOB',
#   'longName': 'Bolivian Boliviano',
#   'symbol': 'BOB',
#   'localLongName': 'Bolivian Boliviano'},
#  {'shortName': 'MDL',
#   'longName': 'Moldovan Leu',
#   'symbol': 'MDL',
#   'localLongName': 'Moldovan Leu'},
#  {'shortName': 'IDR',
#   'longName': 'Indonesian Rupiah',
#   'symbol': 'IDR',
#   'localLongName': 'Indonesian Rupiah'},
#  {'shortName': 'KYD',
#   'longName': 'Cayman Islands Dollar',
#   'symbol': 'KYD',
#   'localLongName': 'Cayman Islands Dollar'},
#  {'shortName': 'AMD',
#   'longName': 'Armenian Dram',
#   'symbol': 'AMD',
#   'localLongName': 'Armenian Dram'},
#  {'shortName': 'TRY',
#   'longName': 'Turkish Lira',
#   'symbol': 'TRY',
#   'localLongName': 'Turkish Lira'},
#  {'shortName': 'SHP',
#   'longName': 'Saint Helena Pound',
#   'symbol': 'SHP',
#   'localLongName': 'Saint Helena Pound'},
#  {'shortName': 'BWP',
#   'longName': 'Botswanan Pula',
#   'symbol': 'BWP',
#   'localLongName': 'Botswanan Pula'},
#  {'shortName': 'LBP',
#   'longName': 'Lebanese Pound',
#   'symbol': 'LBP',
#   'localLongName': 'Lebanese Pound'},
#  {'shortName': 'TJS',
#   'longName': 'Tajikistani Somoni',
#   'symbol': 'TJS',
#   'localLongName': 'Tajikistani Somoni'},
#  {'shortName': 'JOD',
#   'longName': 'Jordanian Dinar',
#   'symbol': 'JOD',
#   'localLongName': 'Jordanian Dinar'},
#  {'shortName': 'HKD',
#   'longName': 'Hong Kong Dollar',
#   'symbol': 'HKD',
#   'localLongName': 'Hong Kong Dollar'},
#  {'shortName': 'RWF',
#   'longName': 'Rwandan Franc',
#   'symbol': 'RWF',
#   'localLongName': 'Rwandan Franc'},
#  {'shortName': 'AED',
#   'longName': 'United Arab Emirates Dirham',
#   'symbol': 'AED',
#   'localLongName': 'United Arab Emirates Dirham'},
#  {'shortName': 'EUR',
#   'longName': 'Euro',
#   'symbol': 'EUR',
#   'localLongName': 'Euro'},
#  {'shortName': 'LSL',
#   'longName': 'Lesotho Loti',
#   'symbol': 'LSL',
#   'localLongName': 'Lesotho Loti'},
#  {'shortName': 'DKK',
#   'longName': 'Danish Krone',
#   'symbol': 'DKK',
#   'localLongName': 'Danish Krone'},
#  {'shortName': 'CAD',
#   'longName': 'Canadian Dollar',
#   'symbol': 'CAD',
#   'localLongName': 'Canadian Dollar'},
#  {'shortName': 'BGN',
#   'longName': 'Bulgarian Lev',
#   'symbol': 'BGN',
#   'localLongName': 'Bulgarian Lev'},
#  {'shortName': 'MMK',
#   'longName': 'Myanma Kyat',
#   'symbol': 'MMK',
#   'localLongName': 'Myanma Kyat'},
#  {'shortName': 'NOK',
#   'longName': 'Norwegian Krone',
#   'symbol': 'NOK',
#   'localLongName': 'Norwegian Krone'},
#  {'shortName': 'MUR',
#   'longName': 'Mauritian Rupee',
#   'symbol': 'MUR',
#   'localLongName': 'Mauritian Rupee'},
#  {'shortName': 'SYP',
#   'longName': 'Syrian Pound',
#   'symbol': 'SYP',
#   'localLongName': 'Syrian Pound'},
#  {'shortName': 'ZWL',
#   'longName': 'Zimbabwean Dollar (2009)',
#   'symbol': 'ZWL',
#   'localLongName': 'Zimbabwean Dollar (2009)'},
#  {'shortName': 'GIP',
#   'longName': 'Gibraltar Pound',
#   'symbol': 'GIP',
#   'localLongName': 'Gibraltar Pound'},
#  {'shortName': 'RON',
#   'longName': 'Romanian Leu',
#   'symbol': 'RON',
#   'localLongName': 'Romanian Leu'},
#  {'shortName': 'LKR',
#   'longName': 'Sri Lankan Rupee',
#   'symbol': 'LKR',
#   'localLongName': 'Sri Lankan Rupee'},
#  {'shortName': 'NGN',
#   'longName': 'Nigerian Naira',
#   'symbol': 'NGN',
#   'localLongName': 'Nigerian Naira'},
#  {'shortName': 'CZK',
#   'longName': 'Czech Republic Koruna',
#   'symbol': 'CZK',
#   'localLongName': 'Czech Republic Koruna'},
#  {'shortName': 'CRC',
#   'longName': 'Costa Rican Colón',
#   'symbol': 'CRC',
#   'localLongName': 'Costa Rican Colón'},
#  {'shortName': 'PKR',
#   'longName': 'Pakistani Rupee',
#   'symbol': 'PKR',
#   'localLongName': 'Pakistani Rupee'},
#  {'shortName': 'XCD',
#   'longName': 'East Caribbean Dollar',
#   'symbol': 'XCD',
#   'localLongName': 'East Caribbean Dollar'},
#  {'shortName': 'ANG',
#   'longName': 'Netherlands Antillean Guilder',
#   'symbol': 'ANG',
#   'localLongName': 'Netherlands Antillean Guilder'},
#  {'shortName': 'HTG',
#   'longName': 'Haitian Gourde',
#   'symbol': 'HTG',
#   'localLongName': 'Haitian Gourde'},
#  {'shortName': 'BHD',
#   'longName': 'Bahraini Dinar',
#   'symbol': 'BHD',
#   'localLongName': 'Bahraini Dinar'},
#  {'shortName': 'SZL',
#   'longName': 'Swazi Lilangeni',
#   'symbol': 'SZL',
#   'localLongName': 'Swazi Lilangeni'},
#  {'shortName': 'SRD',
#   'longName': 'Surinamese Dollar',
#   'symbol': 'SRD',
#   'localLongName': 'Surinamese Dollar'},
#  {'shortName': 'KZT',
#   'longName': 'Kazakhstani Tenge',
#   'symbol': 'KZT',
#   'localLongName': 'Kazakhstani Tenge'},
#  {'shortName': 'SAR',
#   'longName': 'Saudi Riyal',
#   'symbol': 'SAR',
#   'localLongName': 'Saudi Riyal'},
#  {'shortName': 'TTD',
#   'longName': 'Trinidad and Tobago Dollar',
#   'symbol': 'TTD',
#   'localLongName': 'Trinidad and Tobago Dollar'},
#  {'shortName': 'LTL',
#   'longName': 'Lithuanian Litas',
#   'symbol': 'LTL',
#   'localLongName': 'Lithuanian Litas'},
#  {'shortName': 'YER',
#   'longName': 'Yemeni Rial',
#   'symbol': 'YER',
#   'localLongName': 'Yemeni Rial'},
#  {'shortName': 'MVR',
#   'longName': 'Maldivian Rufiyaa',
#   'symbol': 'MVR',
#   'localLongName': 'Maldivian Rufiyaa'},
#  {'shortName': 'AFN',
#   'longName': 'Afghan Afghani',
#   'symbol': 'AFN',
#   'localLongName': 'Afghan Afghani'},
#  {'shortName': 'INR',
#   'longName': 'Indian Rupee',
#   'symbol': 'INR',
#   'localLongName': 'Indian Rupee'},
#  {'shortName': 'AWG',
#   'longName': 'Aruban Florin',
#   'symbol': 'AWG',
#   'localLongName': 'Aruban Florin'},
#  {'shortName': 'KRW',
#   'longName': 'South Korean Won',
#   'symbol': 'KRW',
#   'localLongName': 'South Korean Won'},
#  {'shortName': 'NPR',
#   'longName': 'Nepalese Rupee',
#   'symbol': 'NPR',
#   'localLongName': 'Nepalese Rupee'},
#  {'shortName': 'MNT',
#   'longName': 'Mongolian Tugrik',
#   'symbol': 'MNT',
#   'localLongName': 'Mongolian Tugrik'},
#  {'shortName': 'JPY',
#   'longName': 'Japanese Yen',
#   'symbol': 'JPY',
#   'localLongName': 'Japanese Yen'},
#  {'shortName': 'PLN',
#   'longName': 'Polish Zloty',
#   'symbol': 'PLN',
#   'localLongName': 'Polish Zloty'},
#  {'shortName': 'AOA',
#   'longName': 'Angolan Kwanza',
#   'symbol': 'AOA',
#   'localLongName': 'Angolan Kwanza'},
#  {'shortName': 'SBD',
#   'longName': 'Solomon Islands Dollar',
#   'symbol': 'SBD',
#   'localLongName': 'Solomon Islands Dollar'},
#  {'shortName': 'GBP',
#   'longName': 'British Pound Sterling',
#   'symbol': 'GBP',
#   'localLongName': 'British Pound Sterling'},
#  {'shortName': 'BYN',
#   'longName': 'Belarusian Ruble',
#   'symbol': 'BYN',
#   'localLongName': 'Belarusian Ruble'},
#  {'shortName': 'HUF',
#   'longName': 'Hungarian Forint',
#   'symbol': 'HUF',
#   'localLongName': 'Hungarian Forint'},
#  {'shortName': 'BIF',
#   'longName': 'Burundian Franc',
#   'symbol': 'BIF',
#   'localLongName': 'Burundian Franc'},
#  {'shortName': 'MWK',
#   'longName': 'Malawian Malawi Kwacha',
#   'symbol': 'MWK',
#   'localLongName': 'Malawian Malawi Kwacha'},
#  {'shortName': 'MGA',
#   'longName': 'Malagasy Ariary',
#   'symbol': 'MGA',
#   'localLongName': 'Malagasy Ariary'},
#  {'shortName': 'XDR',
#   'longName': 'Special Drawing Rights',
#   'symbol': 'XDR',
#   'localLongName': 'Special Drawing Rights'},
#  {'shortName': 'BZD',
#   'longName': 'Belize Dollar',
#   'symbol': 'BZD',
#   'localLongName': 'Belize Dollar'},
#  {'shortName': 'BAM',
#   'longName': 'Bosnia-Herzegovina Convertible Mark',
#   'symbol': 'BAM',
#   'localLongName': 'Bosnia-Herzegovina Convertible Mark'},
#  {'shortName': 'EGP',
#   'longName': 'Egyptian Pound',
#   'symbol': 'EGP',
#   'localLongName': 'Egyptian Pound'},
#  {'shortName': 'MOP',
#   'longName': 'Macanese Pataca',
#   'symbol': 'MOP',
#   'localLongName': 'Macanese Pataca'},
#  {'shortName': 'NAD',
#   'longName': 'Namibian Dollar',
#   'symbol': 'NAD',
#   'localLongName': 'Namibian Dollar'},
#  {'shortName': 'NIO',
#   'longName': 'Nicaraguan Córdoba',
#   'symbol': 'NIO',
#   'localLongName': 'Nicaraguan Córdoba'},
#  {'shortName': 'PEN',
#   'longName': 'Peruvian Sol',
#   'symbol': 'PEN',
#   'localLongName': 'Peruvian Sol'},
#  {'shortName': 'WST',
#   'longName': 'Samoan Tala',
#   'symbol': 'WST',
#   'localLongName': 'Samoan Tala'},
#  {'shortName': 'NZD',
#   'longName': 'New Zealand Dollar',
#   'symbol': 'NZD',
#   'localLongName': 'New Zealand Dollar'},
#  {'shortName': 'TMT',
#   'longName': 'Turkmenistani Manat',
#   'symbol': 'TMT',
#   'localLongName': 'Turkmenistani Manat'},
#  {'shortName': 'CLF',
#   'longName': 'Chilean Unit of Account (UF)',
#   'symbol': 'CLF',
#   'localLongName': 'Chilean Unit of Account (UF)'},
#  {'shortName': 'BRL',
#   'longName': 'Brazilian Real',
#   'symbol': 'BRL',
#   'localLongName': 'Brazilian Real'}]

# %%
yq.get_exchanges()
# Out:
#                      Country                   Market, or Index Suffix  \
# 0   United States of America      Chicago Board of Trade (CBOT)   .CBT
# 1   United States of America  Chicago Mercantile Exchange (CME)   .CME
# 2   United States of America                  Dow Jones Indexes    NaN
# 3   United States of America              Nasdaq Stock Exchange    NaN
# 4   United States of America                     ICE Futures US   .NYB
# ..                       ...                                ...    ...
# 74                    Turkey                     Borsa İstanbul    .IS
# 75            United Kingdom                       FTSE Indices    NaN
# 76            United Kingdom              London Stock Exchange     .L
# 77            United Kingdom              London Stock Exchange    .IL
# 78                 Venezuela             Caracas Stock Exchange    .CR
#
#         Delay      Data Provider
# 0      10 min  ICE Data Services
# 1      10 min  ICE Data Services
# 2   Real-time  ICE Data Services
# 3   Real-time  ICE Data Services
# 4      30 min  ICE Data Services
# ..        ...                ...
# 74     15 min  ICE Data Services
# 75     15 min  ICE Data Services
# 76     20 min  ICE Data Services
# 77     20 min  ICE Data Services
# 78     15 min  ICE Data Services
#
# [79 rows x 5 columns]

# %%
yq.get_market_summary()
# Out:
# [{'fullExchangeName': 'CME',
#   'symbol': 'ES=F',
#   'headSymbolAsString': 'ES=F',
#   'gmtOffSetMilliseconds': -14400000,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1679025450, 'fmt': '11:57PM EDT'},
#   'regularMarketChangePercent': {'raw': 0.0, 'fmt': '0.00%'},
#   'quoteType': 'FUTURE',
#   'headSymbol': True,
#   'typeDisp': 'Futures',
#   'tradeable': False,
#   'contractSymbol': False,
#   'regularMarketPreviousClose': {'raw': 3960.5, 'fmt': '3,960.50'},
#   'exchangeTimezoneName': 'America/New_York',
#   'regularMarketChange': {'raw': 0.0, 'fmt': '0.00'},
#   'cryptoTradeable': False,
#   'firstTradeDateMilliseconds': 969249600000,
#   'exchangeDataDelayedBy': 10,
#   'exchangeTimezoneShortName': 'EDT',
#   'customPriceAlertConfidence': 'NONE',
#   'regularMarketPrice': {'raw': 3960.5, 'fmt': '3,960.50'},
#   'marketState': 'REGULAR',
#   'market': 'us24_market',
#   'quoteSourceName': 'Delayed Quote',
#   'exchange': 'CME',
#   'sourceInterval': 10,
#   'shortName': 'S&P Futures',
#   'region': 'US',
#   'triggerable': False},
#  {'fullExchangeName': 'CBOT',
#   'symbol': 'YM=F',
#   'headSymbolAsString': 'YM=F',
#   'gmtOffSetMilliseconds': -14400000,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1679025315, 'fmt': '11:55PM EDT'},
#   'regularMarketChangePercent': {'raw': -0.08062266, 'fmt': '-0.08%'},
#   'quoteType': 'FUTURE',
#   'headSymbol': True,
#   'typeDisp': 'Futures',
#   'tradeable': False,
#   'contractSymbol': False,
#   'regularMarketPreviousClose': {'raw': 32249.0, 'fmt': '32,249.00'},
#   'exchangeTimezoneName': 'America/New_York',
#   'regularMarketChange': {'raw': -26.0, 'fmt': '-26.00'},
#   'cryptoTradeable': False,
#   'firstTradeDateMilliseconds': 1017982800000,
#   'exchangeDataDelayedBy': 10,
#   'exchangeTimezoneShortName': 'EDT',
#   'customPriceAlertConfidence': 'NONE',
#   'regularMarketPrice': {'raw': 32223.0, 'fmt': '32,223.00'},
#   'marketState': 'REGULAR',
#   'market': 'us24_market',
#   'quoteSourceName': 'Delayed Quote',
#   'exchange': 'CBT',
#   'sourceInterval': 10,
#   'shortName': 'Dow Futures',
#   'region': 'US',
#   'triggerable': False},
#  {'fullExchangeName': 'CME',
#   'symbol': 'NQ=F',
#   'headSymbolAsString': 'NQ=F',
#   'gmtOffSetMilliseconds': -14400000,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1679025437, 'fmt': '11:57PM EDT'},
#   'regularMarketChangePercent': {'raw': 0.06556465, 'fmt': '0.07%'},
#   'quoteType': 'FUTURE',
#   'headSymbol': True,
#   'typeDisp': 'Futures',
#   'tradeable': False,
#   'contractSymbol': False,
#   'regularMarketPreviousClose': {'raw': 12583.0, 'fmt': '12,583.00'},
#   'exchangeTimezoneName': 'America/New_York',
#   'regularMarketChange': {'raw': 8.25, 'fmt': '8.25'},
#   'cryptoTradeable': False,
#   'firstTradeDateMilliseconds': 969249600000,
#   'exchangeDataDelayedBy': 10,
#   'exchangeTimezoneShortName': 'EDT',
#   'customPriceAlertConfidence': 'NONE',
#   'regularMarketPrice': {'raw': 12591.25, 'fmt': '12,591.25'},
#   'marketState': 'REGULAR',
#   'market': 'us24_market',
#   'quoteSourceName': 'Delayed Quote',
#   'exchange': 'CME',
#   'sourceInterval': 10,
#   'shortName': 'Nasdaq Futures',
#   'region': 'US',
#   'triggerable': False},
#  {'fullExchangeName': 'CME',
#   'symbol': 'RTY=F',
#   'headSymbolAsString': 'RTY=F',
#   'gmtOffSetMilliseconds': -14400000,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1679025425, 'fmt': '11:57PM EDT'},
#   'regularMarketChangePercent': {'raw': -0.13435799, 'fmt': '-0.13%'},
#   'quoteType': 'FUTURE',
#   'headSymbol': True,
#   'typeDisp': 'Futures',
#   'tradeable': False,
#   'contractSymbol': False,
#   'regularMarketPreviousClose': {'raw': 1786.2, 'fmt': '1,786.20'},
#   'exchangeTimezoneName': 'America/New_York',
#   'regularMarketChange': {'raw': -2.3999023, 'fmt': '-2.40'},
#   'cryptoTradeable': False,
#   'firstTradeDateMilliseconds': 1499659200000,
#   'exchangeDataDelayedBy': 10,
#   'exchangeTimezoneShortName': 'EDT',
#   'customPriceAlertConfidence': 'NONE',
#   'regularMarketPrice': {'raw': 1783.8, 'fmt': '1,783.80'},
#   'marketState': 'REGULAR',
#   'market': 'us24_market',
#   'quoteSourceName': 'Delayed Quote',
#   'exchange': 'CME',
#   'sourceInterval': 10,
#   'shortName': 'Russell 2000 Futures',
#   'region': 'US',
#   'triggerable': False},
#  {'fullExchangeName': 'NY Mercantile',
#   'symbol': 'CL=F',
#   'headSymbolAsString': 'CL=F',
#   'gmtOffSetMilliseconds': -14400000,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1679025410, 'fmt': '11:56PM EDT'},
#   'regularMarketChangePercent': {'raw': 1.1411833, 'fmt': '1.14%'},
#   'quoteType': 'FUTURE',
#   'headSymbol': True,
#   'typeDisp': 'Futures',
#   'tradeable': False,
#   'contractSymbol': False,
#   'regularMarketPreviousClose': {'raw': 68.35, 'fmt': '68.35'},
#   'exchangeTimezoneName': 'America/New_York',
#   'regularMarketChange': {'raw': 0.7799988, 'fmt': '0.78'},
#   'cryptoTradeable': False,
#   'firstTradeDateMilliseconds': 967003200000,
#   'exchangeDataDelayedBy': 10,
#   'exchangeTimezoneShortName': 'EDT',
#   'customPriceAlertConfidence': 'NONE',
#   'regularMarketPrice': {'raw': 69.13, 'fmt': '69.13'},
#   'marketState': 'REGULAR',
#   'market': 'us24_market',
#   'quoteSourceName': 'Delayed Quote',
#   'exchange': 'NYM',
#   'sourceInterval': 30,
#   'shortName': 'Crude Oil',
#   'region': 'US',
#   'triggerable': False},
#  {'fullExchangeName': 'COMEX',
#   'symbol': 'GC=F',
#   'headSymbolAsString': 'GC=F',
#   'gmtOffSetMilliseconds': -14400000,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1679025451, 'fmt': '11:57PM EDT'},
#   'regularMarketChangePercent': {'raw': 0.45241556, 'fmt': '0.45%'},
#   'quoteType': 'FUTURE',
#   'headSymbol': True,
#   'typeDisp': 'Futures',
#   'tradeable': False,
#   'contractSymbol': False,
#   'regularMarketPreviousClose': {'raw': 1923.0, 'fmt': '1,923.00'},
#   'exchangeTimezoneName': 'America/New_York',
#   'regularMarketChange': {'raw': 8.699951, 'fmt': '8.70'},
#   'cryptoTradeable': False,
#   'firstTradeDateMilliseconds': 967608000000,
#   'exchangeDataDelayedBy': 10,
#   'exchangeTimezoneShortName': 'EDT',
#   'customPriceAlertConfidence': 'NONE',
#   'regularMarketPrice': {'raw': 1931.7, 'fmt': '1,931.70'},
#   'marketState': 'REGULAR',
#   'market': 'us24_market',
#   'quoteSourceName': 'Delayed Quote',
#   'exchange': 'CMX',
#   'sourceInterval': 15,
#   'shortName': 'Gold',
#   'region': 'US',
#   'triggerable': False},
#  {'fullExchangeName': 'COMEX',
#   'symbol': 'SI=F',
#   'headSymbolAsString': 'SI=F',
#   'gmtOffSetMilliseconds': -14400000,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1679025411, 'fmt': '11:56PM EDT'},
#   'regularMarketChangePercent': {'raw': 1.6503772, 'fmt': '1.65%'},
#   'quoteType': 'FUTURE',
#   'headSymbol': True,
#   'typeDisp': 'Futures',
#   'tradeable': False,
#   'contractSymbol': False,
#   'regularMarketPreviousClose': {'raw': 21.692, 'fmt': '21.69'},
#   'exchangeTimezoneName': 'America/New_York',
#   'regularMarketChange': {'raw': 0.3579998, 'fmt': '0.36'},
#   'cryptoTradeable': False,
#   'firstTradeDateMilliseconds': 967608000000,
#   'exchangeDataDelayedBy': 10,
#   'exchangeTimezoneShortName': 'EDT',
#   'customPriceAlertConfidence': 'NONE',
#   'regularMarketPrice': {'raw': 22.05, 'fmt': '22.05'},
#   'marketState': 'REGULAR',
#   'market': 'us24_market',
#   'quoteSourceName': 'Delayed Quote',
#   'exchange': 'CMX',
#   'sourceInterval': 15,
#   'shortName': 'Silver',
#   'region': 'US',
#   'triggerable': False},
#  {'fullExchangeName': 'CCY',
#   'symbol': 'EURUSD=X',
#   'gmtOffSetMilliseconds': 0,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1679026022, 'fmt': '4:07AM GMT'},
#   'regularMarketChangePercent': {'raw': 0.23414297, 'fmt': '0.23%'},
#   'quoteType': 'CURRENCY',
#   'typeDisp': 'Currency',
#   'tradeable': False,
#   'currency': 'USD',
#   'regularMarketPreviousClose': {'raw': 1.0617965, 'fmt': '1.0618'},
#   'exchangeTimezoneName': 'Europe/London',
#   'regularMarketChange': {'raw': 0.0024861097, 'fmt': '0.0025'},
#   'cryptoTradeable': False,
#   'exchangeDataDelayedBy': 0,
#   'firstTradeDateMilliseconds': 1070236800000,
#   'exchangeTimezoneShortName': 'GMT',
#   'regularMarketPrice': {'raw': 1.0642827, 'fmt': '1.0643'},
#   'customPriceAlertConfidence': 'LOW',
#   'marketState': 'REGULAR',
#   'market': 'ccy_market',
#   'quoteSourceName': 'Delayed Quote',
#   'priceHint': 4,
#   'exchange': 'CCY',
#   'sourceInterval': 15,
#   'shortName': 'EUR/USD',
#   'region': 'US',
#   'triggerable': False},
#  {'fullExchangeName': 'ICE Futures',
#   'symbol': '^TNX',
#   'gmtOffSetMilliseconds': -14400000,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1678993196, 'fmt': '2:59PM EDT'},
#   'regularMarketChangePercent': {'raw': 2.6632285, 'fmt': '2.66%'},
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'tradeable': False,
#   'regularMarketPreviousClose': {'raw': 3.4919999, 'fmt': '3.4920'},
#   'exchangeTimezoneName': 'America/New_York',
#   'regularMarketChange': {'raw': 0.092999935, 'fmt': '0.0930'},
#   'cryptoTradeable': False,
#   'exchangeDataDelayedBy': 10,
#   'firstTradeDateMilliseconds': -252356400000,
#   'exchangeTimezoneShortName': 'EDT',
#   'marketState': 'REGULAR',
#   'regularMarketPrice': {'raw': 3.5849998, 'fmt': '3.5850'},
#   'customPriceAlertConfidence': 'LOW',
#   'market': 'us24_market',
#   'priceHint': 4,
#   'exchange': 'NYB',
#   'sourceInterval': 30,
#   'region': 'US',
#   'shortName': '10-Yr Bond',
#   'triggerable': False,
#   'longName': 'Treasury Yield 10 Years'},
#  {'fullExchangeName': 'Chicago Options',
#   'symbol': '^VIX',
#   'gmtOffSetMilliseconds': -14400000,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1678997701, 'fmt': '4:15PM EDT'},
#   'regularMarketChangePercent': {'raw': -12.050496, 'fmt': '-12.05%'},
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'tradeable': False,
#   'regularMarketPreviousClose': {'raw': 26.14, 'fmt': '26.14'},
#   'exchangeTimezoneName': 'America/New_York',
#   'regularMarketChange': {'raw': -3.1499996, 'fmt': '-3.15'},
#   'cryptoTradeable': False,
#   'exchangeDataDelayedBy': 15,
#   'firstTradeDateMilliseconds': 631290600000,
#   'exchangeTimezoneShortName': 'EDT',
#   'marketState': 'PREPRE',
#   'regularMarketPrice': {'raw': 22.99, 'fmt': '22.99'},
#   'customPriceAlertConfidence': 'LOW',
#   'market': 'us_market',
#   'quoteSourceName': 'Delayed Quote',
#   'priceHint': 2,
#   'exchange': 'WCB',
#   'sourceInterval': 15,
#   'region': 'US',
#   'shortName': 'Vix',
#   'triggerable': False,
#   'longName': 'CBOE Volatility Index'},
#  {'fullExchangeName': 'CCY',
#   'symbol': 'GBPUSD=X',
#   'gmtOffSetMilliseconds': 0,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1679026022, 'fmt': '4:07AM GMT'},
#   'regularMarketChangePercent': {'raw': 0.27690366, 'fmt': '0.28%'},
#   'quoteType': 'CURRENCY',
#   'typeDisp': 'Currency',
#   'tradeable': False,
#   'currency': 'USD',
#   'regularMarketPreviousClose': {'raw': 1.2111377, 'fmt': '1.2111'},
#   'exchangeTimezoneName': 'Europe/London',
#   'regularMarketChange': {'raw': 0.0033535957, 'fmt': '0.0034'},
#   'cryptoTradeable': False,
#   'exchangeDataDelayedBy': 0,
#   'firstTradeDateMilliseconds': 1070236800000,
#   'exchangeTimezoneShortName': 'GMT',
#   'regularMarketPrice': {'raw': 1.2144912, 'fmt': '1.2145'},
#   'customPriceAlertConfidence': 'LOW',
#   'marketState': 'REGULAR',
#   'market': 'ccy_market',
#   'quoteSourceName': 'Delayed Quote',
#   'priceHint': 4,
#   'exchange': 'CCY',
#   'sourceInterval': 15,
#   'shortName': 'GBP/USD',
#   'region': 'US',
#   'triggerable': False,
#   'longName': 'USD/GBP'},
#  {'fullExchangeName': 'CCY',
#   'symbol': 'JPY=X',
#   'gmtOffSetMilliseconds': 0,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1679026057, 'fmt': '4:07AM GMT'},
#   'regularMarketChangePercent': {'raw': -0.25153556, 'fmt': '-0.25%'},
#   'quoteType': 'CURRENCY',
#   'typeDisp': 'Currency',
#   'tradeable': False,
#   'currency': 'JPY',
#   'regularMarketPreviousClose': {'raw': 133.585, 'fmt': '133.5850'},
#   'exchangeTimezoneName': 'Europe/London',
#   'regularMarketChange': {'raw': -0.3360138, 'fmt': '-0.3360'},
#   'cryptoTradeable': False,
#   'exchangeDataDelayedBy': 0,
#   'firstTradeDateMilliseconds': 846633600000,
#   'exchangeTimezoneShortName': 'GMT',
#   'regularMarketPrice': {'raw': 133.249, 'fmt': '133.2490'},
#   'customPriceAlertConfidence': 'LOW',
#   'marketState': 'REGULAR',
#   'market': 'ccy_market',
#   'quoteSourceName': 'Delayed Quote',
#   'priceHint': 4,
#   'exchange': 'CCY',
#   'sourceInterval': 15,
#   'shortName': 'USD/JPY',
#   'region': 'US',
#   'triggerable': False,
#   'longName': 'USD/JPY'},
#  {'fullExchangeName': 'CCC',
#   'symbol': 'BTC-USD',
#   'gmtOffSetMilliseconds': 0,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1679025900, 'fmt': '4:05AM UTC'},
#   'regularMarketChangePercent': {'raw': 6.16627, 'fmt': '6.17%'},
#   'quoteType': 'CRYPTOCURRENCY',
#   'typeDisp': 'Cryptocurrency',
#   'tradeable': False,
#   'regularMarketPreviousClose': {'raw': 25020.943, 'fmt': '25,020.94'},
#   'exchangeTimezoneName': 'UTC',
#   'regularMarketChange': {'raw': 1499.7773, 'fmt': '1,499.78'},
#   'cryptoTradeable': True,
#   'exchangeDataDelayedBy': 0,
#   'firstTradeDateMilliseconds': 1410912000000,
#   'exchangeTimezoneShortName': 'UTC',
#   'marketState': 'REGULAR',
#   'regularMarketPrice': {'raw': 25822.066, 'fmt': '25,822.07'},
#   'customPriceAlertConfidence': 'LOW',
#   'market': 'ccc_market',
#   'quoteSourceName': 'CoinMarketCap',
#   'exchange': 'CCC',
#   'sourceInterval': 15,
#   'region': 'US',
#   'shortName': 'Bitcoin USD',
#   'triggerable': False,
#   'longName': 'Bitcoin USD'},
#  {'fullExchangeName': 'Nasdaq GIDS',
#   'symbol': '^CMC200',
#   'gmtOffSetMilliseconds': -14400000,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1679025989, 'fmt': '12:06AM EDT'},
#   'regularMarketChangePercent': {'raw': 5.219028, 'fmt': '5.22%'},
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'tradeable': False,
#   'regularMarketPreviousClose': {'raw': 542.6147, 'fmt': '542.61'},
#   'exchangeTimezoneName': 'America/New_York',
#   'regularMarketChange': {'raw': 28.319214, 'fmt': '28.32'},
#   'cryptoTradeable': False,
#   'exchangeDataDelayedBy': 0,
#   'firstTradeDateMilliseconds': 1546266600000,
#   'exchangeTimezoneShortName': 'EDT',
#   'marketState': 'PREPRE',
#   'regularMarketPrice': {'raw': 570.9339, 'fmt': '570.93'},
#   'customPriceAlertConfidence': 'LOW',
#   'market': 'us_market',
#   'quoteSourceName': 'Delayed Quote',
#   'priceHint': 2,
#   'exchange': 'NIM',
#   'sourceInterval': 15,
#   'region': 'US',
#   'shortName': 'CMC Crypto 200',
#   'triggerable': False,
#   'longName': 'CMC Crypto 200 Index by Solacti'},
#  {'fullExchangeName': 'FTSE Index',
#   'symbol': '^FTSE',
#   'gmtOffSetMilliseconds': 0,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1678984530, 'fmt': '4:35PM GMT'},
#   'regularMarketChangePercent': {'raw': 0.8929135, 'fmt': '0.89%'},
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'tradeable': False,
#   'regularMarketPreviousClose': {'raw': 7344.45, 'fmt': '7,344.45'},
#   'exchangeTimezoneName': 'Europe/London',
#   'regularMarketChange': {'raw': 65.57959, 'fmt': '65.58'},
#   'cryptoTradeable': False,
#   'exchangeDataDelayedBy': 15,
#   'firstTradeDateMilliseconds': 441964800000,
#   'exchangeTimezoneShortName': 'GMT',
#   'marketState': 'PREPRE',
#   'regularMarketPrice': {'raw': 7410.03, 'fmt': '7,410.03'},
#   'customPriceAlertConfidence': 'LOW',
#   'market': 'gb_market',
#   'quoteSourceName': 'Delayed Quote',
#   'priceHint': 2,
#   'exchange': 'FGI',
#   'sourceInterval': 15,
#   'region': 'US',
#   'shortName': 'FTSE 100',
#   'triggerable': False,
#   'longName': 'FTSE 100'},
#  {'fullExchangeName': 'Osaka',
#   'symbol': '^N225',
#   'gmtOffSetMilliseconds': 32400000,
#   'language': 'en-US',
#   'regularMarketTime': {'raw': 1679024855, 'fmt': '12:47PM JST'},
#   'regularMarketChangePercent': {'raw': 0.7302686, 'fmt': '0.73%'},
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'tradeable': False,
#   'regularMarketPreviousClose': {'raw': 27010.61, 'fmt': '27,010.61'},
#   'exchangeTimezoneName': 'Asia/Tokyo',
#   'regularMarketChange': {'raw': 197.25, 'fmt': '197.25'},
#   'cryptoTradeable': False,
#   'exchangeDataDelayedBy': 20,
#   'firstTradeDateMilliseconds': -157420800000,
#   'exchangeTimezoneShortName': 'JST',
#   'marketState': 'REGULAR',
#   'regularMarketPrice': {'raw': 27207.86, 'fmt': '27,207.86'},
#   'customPriceAlertConfidence': 'LOW',
#   'market': 'jp_market',
#   'quoteSourceName': 'Delayed Quote',
#   'priceHint': 2,
#   'exchange': 'OSA',
#   'sourceInterval': 20,
#   'region': 'US',
#   'shortName': 'Nikkei 225',
#   'triggerable': False,
#   'longName': 'Nikkei 225'}]

# %%
yq.get_trending()
# Out:
# {'count': 20,
#  'quotes': [{'symbol': 'BTC-USD'},
#   {'symbol': 'FDX'},
#   {'symbol': 'FRC'},
#   {'symbol': 'NVDA'},
#   {'symbol': 'INTC'},
#   {'symbol': 'AMD'},
#   {'symbol': 'MSFT'},
#   {'symbol': 'CRBP'},
#   {'symbol': 'BTC-CAD'},
#   {'symbol': 'HNST'},
#   {'symbol': 'FRC-PH'},
#   {'symbol': 'SRPT'},
#   {'symbol': 'BIDU'},
#   {'symbol': 'ETH-USD'},
#   {'symbol': 'UPS'},
#   {'symbol': '9888.HK'},
#   {'symbol': 'MARA'},
#   {'symbol': 'AMZN'},
#   {'symbol': 'ENZ'},
#   {'symbol': 'HUBC'}],
#  'jobTimestamp': 1679025444945,
#  'startInterval': 202303170300}

# %%
yq.search("38141G104", first_quote=True)
# Out:
# {'exchange': 'NYQ',
#  'shortname': 'Goldman Sachs Group, Inc. (The)',
#  'quoteType': 'EQUITY',
#  'symbol': 'GS',
#  'index': 'quotes',
#  'score': 121343.0,
#  'typeDisp': 'Equity',
#  'longname': 'The Goldman Sachs Group, Inc.',
#  'exchDisp': 'NYSE',
#  'sector': 'Financial Services',
#  'industry': 'Capital Markets',
#  'isYahooFinance': True}

# %%
aapl.asset_profile
# Out:
# {'aapl': {'address1': 'One Apple Park Way',
#   'city': 'Cupertino',
#   'state': 'CA',
#   'zip': '95014',
#   'country': 'United States',
#   'phone': '408 996 1010',
#   'website': 'https://www.apple.com',
#   'industry': 'Consumer Electronics',
#   'sector': 'Technology',
#   'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was incorporated in 1977 and is headquartered in Cupertino, California.',
#   'fullTimeEmployees': 164000,
#   'companyOfficers': [{'maxAge': 1,
#     'name': 'Mr. Timothy D. Cook',
#     'age': 61,
#     'title': 'CEO & Director',
#     'yearBorn': 1961,
#     'fiscalYear': 2022,
#     'totalPay': 16425933,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Luca  Maestri',
#     'age': 59,
#     'title': 'CFO & Sr. VP',
#     'yearBorn': 1963,
#     'fiscalYear': 2022,
#     'totalPay': 5019783,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Jeffrey E. Williams',
#     'age': 58,
#     'title': 'Chief Operating Officer',
#     'yearBorn': 1964,
#     'fiscalYear': 2022,
#     'totalPay': 5018337,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Katherine L. Adams',
#     'age': 58,
#     'title': 'Sr. VP, Gen. Counsel & Sec.',
#     'yearBorn': 1964,
#     'fiscalYear': 2022,
#     'totalPay': 5015208,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': "Ms. Deirdre  O'Brien",
#     'age': 55,
#     'title': 'Sr. VP of Retail',
#     'yearBorn': 1967,
#     'fiscalYear': 2022,
#     'totalPay': 5019783,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Chris  Kondo',
#     'title': 'Sr. Director of Corp. Accounting',
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. James  Wilson',
#     'title': 'Chief Technology Officer',
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Mary  Demby',
#     'title': 'Chief Information Officer',
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Nancy  Paxton',
#     'title': 'Sr. Director of Investor Relations & Treasury',
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Greg  Joswiak',
#     'title': 'Sr. VP of Worldwide Marketing',
#     'exercisedValue': 0,
#     'unexercisedValue': 0}],
#   'auditRisk': 3,
#   'boardRisk': 1,
#   'compensationRisk': 5,
#   'shareHolderRightsRisk': 1,
#   'overallRisk': 1,
#   'governanceEpochDate': '2023-03-01 09:00:00',
#   'compensationAsOfEpochDate': '2022-12-31 09:00:00',
#   'maxAge': 86400}}

# %%
aapl.calendar_events
# Out:
# {'aapl': {'maxAge': 1,
#   'earnings': {'earningsDate': ['2023-04-26 19:59:S', '2023-05-01 21:00:S'],
#    'earningsAverage': 1.43,
#    'earningsLow': 1.37,
#    'earningsHigh': 1.56,
#    'revenueAverage': 92976300000,
#    'revenueLow': 91805900000,
#    'revenueHigh': 98836000000},
#   'exDividendDate': '2023-02-10 09:00:00',
#   'dividendDate': '2023-02-16 09:00:00'}}

# %%
aapl.company_officers
# Out:
#             maxAge                     name   age  \
# symbol row
# aapl   0         1      Mr. Timothy D. Cook  61.0
#        1         1        Mr. Luca  Maestri  59.0
#        2         1  Mr. Jeffrey E. Williams  58.0
#        3         1   Ms. Katherine L. Adams  58.0
#        4         1     Ms. Deirdre  O'Brien  55.0
#        5         1         Mr. Chris  Kondo   NaN
#        6         1        Mr. James  Wilson   NaN
#        7         1          Ms. Mary  Demby   NaN
#        8         1        Ms. Nancy  Paxton   NaN
#        9         1        Mr. Greg  Joswiak   NaN
#
#                                                     title  yearBorn  \
# symbol row
# aapl   0                                   CEO & Director    1961.0
#        1                                     CFO & Sr. VP    1963.0
#        2                          Chief Operating Officer    1964.0
#        3                      Sr. VP, Gen. Counsel & Sec.    1964.0
#        4                                 Sr. VP of Retail    1967.0
#        5                 Sr. Director of Corp. Accounting       NaN
#        6                         Chief Technology Officer       NaN
#        7                        Chief Information Officer       NaN
#        8    Sr. Director of Investor Relations & Treasury       NaN
#        9                    Sr. VP of Worldwide Marketing       NaN
#
#             fiscalYear    totalPay  exercisedValue  unexercisedValue
# symbol row
# aapl   0        2022.0  16425933.0               0                 0
#        1        2022.0   5019783.0               0                 0
#        2        2022.0   5018337.0               0                 0
#        3        2022.0   5015208.0               0                 0
#        4        2022.0   5019783.0               0                 0
#        5           NaN         NaN               0                 0
#        6           NaN         NaN               0                 0
#        7           NaN         NaN               0                 0
#        8           NaN         NaN               0                 0
#        9           NaN         NaN               0                 0

# %%
aapl.earning_history
# Out:
#             maxAge  epsActual  epsEstimate  epsDifference  surprisePercent  \
# symbol row
# aapl   0         1       1.52         1.43           0.09            0.063
#        1         1       1.20         1.16           0.04            0.034
#        2         1       1.29         1.27           0.02            0.016
#        3         1       1.88         1.94          -0.06           -0.031
#
#                quarter period
# symbol row
# aapl   0    2022-03-31    -4q
#        1    2022-06-30    -3q
#        2    2022-09-30    -2q
#        3    2022-12-31    -1q

# %%
aapl.earnings
# Out:
# {'aapl': {'maxAge': 86400,
#   'earningsChart': {'quarterly': [{'date': '1Q2022',
#      'actual': 1.52,
#      'estimate': 1.43},
#     {'date': '2Q2022', 'actual': 1.2, 'estimate': 1.16},
#     {'date': '3Q2022', 'actual': 1.29, 'estimate': 1.27},
#     {'date': '4Q2022', 'actual': 1.88, 'estimate': 1.94}],
#    'currentQuarterEstimate': 1.43,
#    'currentQuarterEstimateDate': '1Q',
#    'currentQuarterEstimateYear': 2023,
#    'earningsDate': ['2023-04-26 19:59:S', '2023-05-01 21:00:S']},
#   'financialsChart': {'yearly': [{'date': 2019,
#      'revenue': 260174000000,
#      'earnings': 55256000000},
#     {'date': 2020, 'revenue': 274515000000, 'earnings': 57411000000},
#     {'date': 2021, 'revenue': 365817000000, 'earnings': 94680000000},
#     {'date': 2022, 'revenue': 394328000000, 'earnings': 99803000000}],
#    'quarterly': [{'date': '1Q2022',
#      'revenue': 97278000000,
#      'earnings': 25010000000},
#     {'date': '2Q2022', 'revenue': 82959000000, 'earnings': 19442000000},
#     {'date': '3Q2022', 'revenue': 90146000000, 'earnings': 20721000000},
#     {'date': '4Q2022', 'revenue': 117154000000, 'earnings': 29998000000}]},
#   'financialCurrency': 'USD'}}

# %%
aapl.earnings_trend
# Out:
# {'aapl': {'trend': [{'maxAge': 1,
#     'period': '0q',
#     'endDate': '2023-03-31',
#     'growth': -0.059,
#     'earningsEstimate': {'avg': 1.43,
#      'low': 1.37,
#      'high': 1.56,
#      'yearAgoEps': 1.52,
#      'numberOfAnalysts': 26,
#      'growth': -0.059},
#     'revenueEstimate': {'avg': 92976300000,
#      'low': 91805900000,
#      'high': 98836000000,
#      'numberOfAnalysts': 24,
#      'yearAgoRevenue': 97278000000,
#      'growth': -0.044},
#     'epsTrend': {'current': 1.43,
#      '7daysAgo': 1.43,
#      '30daysAgo': 1.43,
#      '60daysAgo': 1.5,
#      '90daysAgo': 1.49},
#     'epsRevisions': {'upLast7days': 0,
#      'upLast30days': 1,
#      'downLast30days': 0,
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '+1q',
#     'endDate': '2023-06-30',
#     'growth': 0.033,
#     'earningsEstimate': {'avg': 1.24,
#      'low': 1.02,
#      'high': 1.35,
#      'yearAgoEps': 1.2,
#      'numberOfAnalysts': 25,
#      'growth': 0.033},
#     'revenueEstimate': {'avg': 85545000000,
#      'low': 81317700000,
#      'high': 90118000000,
#      'numberOfAnalysts': 23,
#      'yearAgoRevenue': 82959000000,
#      'growth': 0.031},
#     'epsTrend': {'current': 1.24,
#      '7daysAgo': 1.24,
#      '30daysAgo': 1.24,
#      '60daysAgo': 1.25,
#      '90daysAgo': 1.26},
#     'epsRevisions': {'upLast7days': 0,
#      'upLast30days': 0,
#      'downLast30days': 0,
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '0y',
#     'endDate': '2023-09-30',
#     'growth': -0.025,
#     'earningsEstimate': {'avg': 5.96,
#      'low': 5.38,
#      'high': 6.34,
#      'yearAgoEps': 6.11,
#      'numberOfAnalysts': 37,
#      'growth': -0.025},
#     'revenueEstimate': {'avg': 388685000000,
#      'low': 375075000000,
#      'high': 401212000000,
#      'numberOfAnalysts': 36,
#      'yearAgoRevenue': 394328000000,
#      'growth': -0.0139999995},
#     'epsTrend': {'current': 5.96,
#      '7daysAgo': 5.97,
#      '30daysAgo': 5.97,
#      '60daysAgo': 6.19,
#      '90daysAgo': 6.21},
#     'epsRevisions': {'upLast7days': 0,
#      'upLast30days': 2,
#      'downLast30days': 1,
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '+1y',
#     'endDate': '2024-09-30',
#     'growth': 0.109,
#     'earningsEstimate': {'avg': 6.61,
#      'low': 5.62,
#      'high': 7.15,
#      'yearAgoEps': 5.96,
#      'numberOfAnalysts': 35,
#      'growth': 0.109},
#     'revenueEstimate': {'avg': 415574000000,
#      'low': 397121000000,
#      'high': 434476000000,
#      'numberOfAnalysts': 34,
#      'yearAgoRevenue': 388685000000,
#      'growth': 0.069},
#     'epsTrend': {'current': 6.61,
#      '7daysAgo': 6.6,
#      '30daysAgo': 6.58,
#      '60daysAgo': 6.74,
#      '90daysAgo': 6.77},
#     'epsRevisions': {'upLast7days': 0,
#      'upLast30days': 2,
#      'downLast30days': 1,
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '+5y',
#     'endDate': None,
#     'growth': 0.0813,
#     'earningsEstimate': {'avg': {},
#      'low': {},
#      'high': {},
#      'yearAgoEps': {},
#      'numberOfAnalysts': {},
#      'growth': {}},
#     'revenueEstimate': {'avg': {},
#      'low': {},
#      'high': {},
#      'numberOfAnalysts': {},
#      'yearAgoRevenue': {},
#      'growth': {}},
#     'epsTrend': {'current': {},
#      '7daysAgo': {},
#      '30daysAgo': {},
#      '60daysAgo': {},
#      '90daysAgo': {}},
#     'epsRevisions': {'upLast7days': {},
#      'upLast30days': {},
#      'downLast30days': {},
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '-5y',
#     'endDate': None,
#     'growth': 0.21908002,
#     'earningsEstimate': {'avg': {},
#      'low': {},
#      'high': {},
#      'yearAgoEps': {},
#      'numberOfAnalysts': {},
#      'growth': {}},
#     'revenueEstimate': {'avg': {},
#      'low': {},
#      'high': {},
#      'numberOfAnalysts': {},
#      'yearAgoRevenue': {},
#      'growth': {}},
#     'epsTrend': {'current': {},
#      '7daysAgo': {},
#      '30daysAgo': {},
#      '60daysAgo': {},
#      '90daysAgo': {}},
#     'epsRevisions': {'upLast7days': {},
#      'upLast30days': {},
#      'downLast30days': {},
#      'downLast90days': {}}}],
#   'maxAge': 1}}

# %%
aapl.esg_scores
# Out:
# {'aapl': {'maxAge': 86400,
#   'totalEsg': 16.68,
#   'environmentScore': 0.65,
#   'socialScore': 6.86,
#   'governanceScore': 9.18,
#   'ratingYear': 2022,
#   'ratingMonth': 8,
#   'highestControversy': 3.0,
#   'peerCount': 55,
#   'esgPerformance': 'UNDER_PERF',
#   'peerGroup': 'Technology Hardware',
#   'relatedControversy': ['Social Supply Chain Incidents',
#    'Customer Incidents',
#    'Business Ethics Incidents'],
#   'peerEsgScorePerformance': {'min': 5.97,
#    'avg': 16.164727272727273,
#    'max': 25.7},
#   'peerGovernancePerformance': {'min': 3.45,
#    'avg': 7.1781481481481455,
#    'max': 11.5},
#   'peerSocialPerformance': {'min': 2.24,
#    'avg': 6.082037037037039,
#    'max': 12.55},
#   'peerEnvironmentPerformance': {'min': 0.03,
#    'avg': 3.093703703703704,
#    'max': 8.67},
#   'peerHighestControversyPerformance': {'min': 0.0,
#    'avg': 1.5454545454545454,
#    'max': 4.0},
#   'percentile': 14.68,
#   'environmentPercentile': None,
#   'socialPercentile': None,
#   'governancePercentile': None,
#   'adult': False,
#   'alcoholic': False,
#   'animalTesting': False,
#   'catholic': False,
#   'controversialWeapons': False,
#   'smallArms': False,
#   'furLeather': False,
#   'gambling': False,
#   'gmo': False,
#   'militaryContract': False,
#   'nuclear': False,
#   'pesticides': False,
#   'palmOil': False,
#   'coal': False,
#   'tobacco': False}}

# %%
aapl.history(start='2023-03-11', period='7d', interval='1m')
# Out:
#                                         open        high         low  \
# symbol date
# aapl   2023-03-10 10:00:00-05:00  149.789993  150.190002  149.779999
#        2023-03-10 10:01:00-05:00  150.179993  150.330002  150.089996
#        2023-03-10 10:02:00-05:00  150.270004  150.270004  150.000000
#        2023-03-10 10:03:00-05:00  150.161194  150.421204  150.000000
#        2023-03-10 10:04:00-05:00  150.000000  150.210007  149.960007
# ...                                      ...         ...         ...
#        2023-03-16 15:56:00-04:00  155.679993  155.919998  155.660004
#        2023-03-16 15:57:00-04:00  155.914993  156.029907  155.904999
#        2023-03-16 15:58:00-04:00  155.949997  155.960007  155.839996
#        2023-03-16 15:59:00-04:00  155.899994  155.929993  155.809998
#        2023-03-16 16:00:00-04:00  155.850006  155.850006  155.850006
#
#                                        close     volume
# symbol date
# aapl   2023-03-10 10:00:00-05:00  150.180099        0.0
#        2023-03-10 10:01:00-05:00  150.270096   289752.0
#        2023-03-10 10:02:00-05:00  150.160095   204724.0
#        2023-03-10 10:03:00-05:00  150.000000   329590.0
#        2023-03-10 10:04:00-05:00  150.085007   264868.0
# ...                                      ...        ...
#        2023-03-16 15:56:00-04:00  155.910004   441635.0
#        2023-03-16 15:57:00-04:00  155.960007   432476.0
#        2023-03-16 15:58:00-04:00  155.899994   567975.0
#        2023-03-16 15:59:00-04:00  155.910004  1112682.0
#        2023-03-16 16:00:00-04:00  155.850006        0.0
#
# [1919 rows x 5 columns]

# %%
aapl.history(start='2023-03-01', end='2023-03-06', interval='1m')
# Out:
#                                         open        high         low  \
# symbol date
# aapl   2023-02-28 10:00:00-05:00  147.710007  147.948105  147.610001
#        2023-02-28 10:01:00-05:00  147.880005  147.970001  147.699997
#        2023-02-28 10:02:00-05:00  147.740005  147.774994  147.619995
#        2023-02-28 10:03:00-05:00  147.679993  147.889999  147.664993
#        2023-02-28 10:04:00-05:00  147.869995  147.970001  147.800003
# ...                                      ...         ...         ...
#        2023-03-03 15:56:00-05:00  150.895004  151.000000  150.889999
#        2023-03-03 15:57:00-05:00  150.945007  151.009995  150.925003
#        2023-03-03 15:58:00-05:00  151.000000  151.029999  150.929993
#        2023-03-03 15:59:00-05:00  151.024994  151.110001  150.979996
#        2023-03-16 16:00:00-04:00  155.850006  155.850006  155.850006
#
#                                        close   volume
# symbol date
# aapl   2023-02-28 10:00:00-05:00  147.874405        0
#        2023-02-28 10:01:00-05:00  147.748596   167091
#        2023-02-28 10:02:00-05:00  147.675003   155225
#        2023-02-28 10:03:00-05:00  147.860001   134777
#        2023-02-28 10:04:00-05:00  147.860001   126979
# ...                                      ...      ...
#        2023-03-03 15:56:00-05:00  150.942093   417774
#        2023-03-03 15:57:00-05:00  151.000000   481210
#        2023-03-03 15:58:00-05:00  151.024994   469167
#        2023-03-03 15:59:00-05:00  151.100006  1012203
#        2023-03-16 16:00:00-04:00  155.850006        0
#
# [1531 rows x 5 columns]

# %%
aapl = aapl.history(period='7d', interval='1m')
aapl.to_csv("C:/Users/SSAFY/Desktop/gio/data-preprocessing/aapl.csv", sep=',', encoding='euc-kr')

# %%
# 1분
interval='1m'
# fetch data by interval (including intraday if period < 60 days)
# valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
# (optional, default is '1d')
# for i in range(2, 5):
#     for j in range(5):
#         start_date = '2023-'+str(i)+'-'+str(j*7+1)
#         end_date = '2023-'+str(i)+'-'+str((j+1)*7)
#         df1= aapl.history(start=start_date, end=end_date, interval=interval)
#         df = pd.concat([df, df1], axis= 0)

# df
from datetime import datetime, timedelta
end = datetime.today()
for i in range(1, 5):
    start = end-timedelta(days=7)
    a = aapl.history(start=start, end=end, interval=interval)
    end = start

    
# df
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[208], line 18
#      16 for i in range(1, 5):
#      17     start = end-timedelta(days=7)
# ---> 18     a = aapl.history(start=start, end=end, interval=interval)
#      19     end = start
#      22 # df
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'history'

# %%
interval='1m'
# fetch data by interval (including intraday if period < 60 days)
# valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
# (optional, default is '1d')
for i in range(2, 5):
    for j in range(1,5):
        start_date = '2023-'+str(i)+'-'+str(j*7+1)
        end_date = '2023-'+str(i)+'-'+str((j+1)*7)
        df1= yf.download('AAPL', start=start_date, end=end_date, interval=interval)
        df = pd.concat([df, df1], axis= 1)

df
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: 1m data not available for startTime=1675832400 and endTime=1676350800. The requested range must be within the last 30 days.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: ValueError('unconverted data remains: 5')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: Data doesn't exist for startDate = 1679457600, endDate = 1679976000
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: ValueError('unconverted data remains: 5')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: Data doesn't exist for startDate = 1680926400, endDate = 1681444800
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: Data doesn't exist for startDate = 1681531200, endDate = 1682049600
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: Data doesn't exist for startDate = 1682136000, endDate = 1682654400
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: ValueError('unconverted data remains: 5')
#                                          high         low  volume        open  \
# (aapl, 2023-02-21 10:00:00-05:00)  150.449997  150.139999       0  150.360001
# (aapl, 2023-02-21 10:01:00-05:00)  150.610001  150.375000  196858  150.389999
# (aapl, 2023-02-21 10:02:00-05:00)  150.470001  150.309998  111916  150.460098
# (aapl, 2023-02-21 10:03:00-05:00)  150.410004  150.259995  135462  150.359207
# (aapl, 2023-02-21 10:04:00-05:00)  150.399994  150.250000  198006  150.309998
# ...                                       ...         ...     ...         ...
# (aapl, 2023-02-21 09:55:00-05:00)         NaN         NaN     NaN         NaN
# (aapl, 2023-02-21 09:56:00-05:00)         NaN         NaN     NaN         NaN
# (aapl, 2023-02-21 09:57:00-05:00)         NaN         NaN     NaN         NaN
# (aapl, 2023-02-21 09:58:00-05:00)         NaN         NaN     NaN         NaN
# (aapl, 2023-02-21 09:59:00-05:00)         NaN         NaN     NaN         NaN
#
#                                         close  Open  High  Low  Close  \
# (aapl, 2023-02-21 10:00:00-05:00)  150.395004   NaN   NaN  NaN    NaN
# (aapl, 2023-02-21 10:01:00-05:00)  150.487900   NaN   NaN  NaN    NaN
# (aapl, 2023-02-21 10:02:00-05:00)  150.359894   NaN   NaN  NaN    NaN
# (aapl, 2023-02-21 10:03:00-05:00)  150.309998   NaN   NaN  NaN    NaN
# (aapl, 2023-02-21 10:04:00-05:00)  150.350006   NaN   NaN  NaN    NaN
# ...                                       ...   ...   ...  ...    ...
# (aapl, 2023-02-21 09:55:00-05:00)         NaN   NaN   NaN  NaN    NaN
# (aapl, 2023-02-21 09:56:00-05:00)         NaN   NaN   NaN  NaN    NaN
# (aapl, 2023-02-21 09:57:00-05:00)         NaN   NaN   NaN  NaN    NaN
# (aapl, 2023-02-21 09:58:00-05:00)         NaN   NaN   NaN  NaN    NaN
# (aapl, 2023-02-21 09:59:00-05:00)         NaN   NaN   NaN  NaN    NaN
#
#                                    Adj Close  ...  Low  Close  Adj Close  \
# (aapl, 2023-02-21 10:00:00-05:00)        NaN  ...  NaN    NaN        NaN
# (aapl, 2023-02-21 10:01:00-05:00)        NaN  ...  NaN    NaN        NaN
# (aapl, 2023-02-21 10:02:00-05:00)        NaN  ...  NaN    NaN        NaN
# (aapl, 2023-02-21 10:03:00-05:00)        NaN  ...  NaN    NaN        NaN
# (aapl, 2023-02-21 10:04:00-05:00)        NaN  ...  NaN    NaN        NaN
# ...                                      ...  ...  ...    ...        ...
# (aapl, 2023-02-21 09:55:00-05:00)        NaN  ...  NaN    NaN        NaN
# (aapl, 2023-02-21 09:56:00-05:00)        NaN  ...  NaN    NaN        NaN
# (aapl, 2023-02-21 09:57:00-05:00)        NaN  ...  NaN    NaN        NaN
# (aapl, 2023-02-21 09:58:00-05:00)        NaN  ...  NaN    NaN        NaN
# (aapl, 2023-02-21 09:59:00-05:00)        NaN  ...  NaN    NaN        NaN
#
#                                    Volume  Open  High  Low  Close  Adj Close  \
# (aapl, 2023-02-21 10:00:00-05:00)     NaN   NaN   NaN  NaN    NaN        NaN
# (aapl, 2023-02-21 10:01:00-05:00)     NaN   NaN   NaN  NaN    NaN        NaN
# (aapl, 2023-02-21 10:02:00-05:00)     NaN   NaN   NaN  NaN    NaN        NaN
# (aapl, 2023-02-21 10:03:00-05:00)     NaN   NaN   NaN  NaN    NaN        NaN
# (aapl, 2023-02-21 10:04:00-05:00)     NaN   NaN   NaN  NaN    NaN        NaN
# ...                                   ...   ...   ...  ...    ...        ...
# (aapl, 2023-02-21 09:55:00-05:00)     NaN   NaN   NaN  NaN    NaN        NaN
# (aapl, 2023-02-21 09:56:00-05:00)     NaN   NaN   NaN  NaN    NaN        NaN
# (aapl, 2023-02-21 09:57:00-05:00)     NaN   NaN   NaN  NaN    NaN        NaN
# (aapl, 2023-02-21 09:58:00-05:00)     NaN   NaN   NaN  NaN    NaN        NaN
# (aapl, 2023-02-21 09:59:00-05:00)     NaN   NaN   NaN  NaN    NaN        NaN
#
#                                    Volume
# (aapl, 2023-02-21 10:00:00-05:00)     NaN
# (aapl, 2023-02-21 10:01:00-05:00)     NaN
# (aapl, 2023-02-21 10:02:00-05:00)     NaN
# (aapl, 2023-02-21 10:03:00-05:00)     NaN
# (aapl, 2023-02-21 10:04:00-05:00)     NaN
# ...                                   ...
# (aapl, 2023-02-21 09:55:00-05:00)     NaN
# (aapl, 2023-02-21 09:56:00-05:00)     NaN
# (aapl, 2023-02-21 09:57:00-05:00)     NaN
# (aapl, 2023-02-21 09:58:00-05:00)     NaN
# (aapl, 2023-02-21 09:59:00-05:00)     NaN
#
# [14037 rows x 499 columns]
