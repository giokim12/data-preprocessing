# %%
import yahooquery as yq
df = yq.get_exchanges()
df
# Out:
#                      Country                   Market, or Index Suffix  \
# 0   United States of America      Chicago Board of Trade (CBOT)   .CBT
# 1   United States of America  Chicago Mercantile Exchange (CME)   .CME
# 2   United States of America                  Dow Jones Indexes    NaN
# 3   United States of America              Nasdaq Stock Exchange    NaN
# 4   United States of America                     ICE Futures US   .NYB
# ..                       ...                                ...    ...
# 74                    Turkey                     Borsa İstanbul    .IS
# 75            United Kingdom                       FTSE Indices    NaN
# 76            United Kingdom              London Stock Exchange     .L
# 77            United Kingdom              London Stock Exchange    .IL
# 78                 Venezuela             Caracas Stock Exchange    .CR
#
#         Delay      Data Provider
# 0      10 min  ICE Data Services
# 1      10 min  ICE Data Services
# ...

# %%
df1 = df['Country'=='Korea']
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# ...
