# %%
import yahooquery as yq
df = yq.get_exchanges()
df
# Out:
#                      Country                   Market, or Index Suffix  \
# 0   United States of America      Chicago Board of Trade (CBOT)   .CBT
# 1   United States of America  Chicago Mercantile Exchange (CME)   .CME
# 2   United States of America                  Dow Jones Indexes    NaN
# 3   United States of America              Nasdaq Stock Exchange    NaN
# 4   United States of America                     ICE Futures US   .NYB
# ..                       ...                                ...    ...
# 74                    Turkey                     Borsa İstanbul    .IS
# 75            United Kingdom                       FTSE Indices    NaN
# 76            United Kingdom              London Stock Exchange     .L
# 77            United Kingdom              London Stock Exchange    .IL
# 78                 Venezuela             Caracas Stock Exchange    .CR
#
#         Delay      Data Provider
# 0      10 min  ICE Data Services
# 1      10 min  ICE Data Services
# ...

# %%
df1 = df[df['Country']=='South Korea']
df1
# Out:
#         Country      Market, or Index Suffix   Delay      Data Provider
# 65  South Korea  Korea Stock Exchange    .KS  20 min  ICE Data Services
# 66  South Korea                KOSDAQ    .KQ  20 min  ICE Data Services

# %%
aapl = yq.Ticker('aapl')
aapl.earnings
# Out:
# {'aapl': {'maxAge': 86400,
#   'earningsChart': {'quarterly': [{'date': '1Q2022',
#      'actual': 1.52,
#      'estimate': 1.43},
#     {'date': '2Q2022', 'actual': 1.2, 'estimate': 1.16},
#     {'date': '3Q2022', 'actual': 1.29, 'estimate': 1.27},
#     {'date': '4Q2022', 'actual': 1.88, 'estimate': 1.94}],
#    'currentQuarterEstimate': 1.43,
#    'currentQuarterEstimateDate': '1Q',
#    'currentQuarterEstimateYear': 2023,
#    'earningsDate': ['2023-04-26 19:59:S', '2023-05-01 21:00:S']},
#   'financialsChart': {'yearly': [{'date': 2019,
#      'revenue': 260174000000,
#      'earnings': 55256000000},
#     {'date': 2020, 'revenue': 274515000000, 'earnings': 57411000000},
#     {'date': 2021, 'revenue': 365817000000, 'earnings': 94680000000},
#     {'date': 2022, 'revenue': 394328000000, 'earnings': 99803000000}],
#    'quarterly': [{'date': '1Q2022',
#      'revenue': 97278000000,
#      'earnings': 25010000000},
# ...

# %%
aapl.earnings_trend
# Out:
# {'aapl': {'trend': [{'maxAge': 1,
#     'period': '0q',
#     'endDate': '2023-03-31',
#     'growth': -0.059,
#     'earningsEstimate': {'avg': 1.43,
#      'low': 1.37,
#      'high': 1.56,
#      'yearAgoEps': 1.52,
#      'numberOfAnalysts': 26,
#      'growth': -0.059},
#     'revenueEstimate': {'avg': 92976300000,
#      'low': 91805900000,
#      'high': 98836000000,
#      'numberOfAnalysts': 24,
#      'yearAgoRevenue': 97278000000,
#      'growth': -0.044},
#     'epsTrend': {'current': 1.43,
#      '7daysAgo': 1.43,
#      '30daysAgo': 1.43,
#      '60daysAgo': 1.49,
#      '90daysAgo': 1.49},
#     'epsRevisions': {'upLast7days': 0,
#      'upLast30days': 1,
#      'downLast30days': 0,
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '+1q',
#     'endDate': '2023-06-30',
#     'growth': 0.033,
#     'earningsEstimate': {'avg': 1.24,
#      'low': 1.02,
#      'high': 1.35,
#      'yearAgoEps': 1.2,
#      'numberOfAnalysts': 25,
#      'growth': 0.033},
# ...

# %%
df = aapl.grading_history
df
# Out:
#                  epochGradeDate                firm     toGrade fromGrade  \
# symbol row
# aapl   0    2023-03-10 22:09:45  LightShed Partners        Sell   Neutral
#        1    2023-03-10 20:54:01             Needham         Buy
#        2    2023-03-08 22:38:22             Wedbush  Outperform
#        3    2023-03-06 19:05:09       Goldman Sachs         Buy
#        4    2023-03-02 23:17:05           Jefferies         Buy
# ...                         ...                 ...         ...       ...
#        889  2012-03-14 17:21:00   Canaccord Genuity         Buy
#        890  2012-03-14 15:13:00      Morgan Stanley  Overweight
#        891  2012-03-13 15:08:00           Jefferies         Buy
#        892  2012-03-08 16:33:00      FBN Securities  Outperform
#        893  2012-02-09 17:17:00   Canaccord Genuity         Buy
#
#            action
# symbol row
# aapl   0     down
#        1     reit
#        2     main
#        3     init
#        4     reit
# ...           ...
# ...

# %%
aapl.index_trend
# Out:
# {'aapl': {'maxAge': 1,
#   'symbol': 'SP5',
#   'peRatio': 17.6096,
#   'pegRatio': 2.11095,
#   'estimates': [{'period': '0q', 'growth': 0.017},
#    {'period': '+1q', 'growth': 0.037},
#    {'period': '0y', 'growth': 0.016},
#    {'period': '+1y', 'growth': 0.113000005},
#    {'period': '+5y', 'growth': 0.0844681},
#    {'period': '-5y'}]}}

# %%
aapl.balance_sheet()
# Out:
#          asOfDate periodType currencyCode  AccountsPayable  \
# symbol
# aapl   2019-09-30        12M          USD     4.623600e+10
# aapl   2020-09-30        12M          USD     4.229600e+10
# aapl   2021-09-30        12M          USD     5.476300e+10
# aapl   2022-09-30        12M          USD     6.411500e+10
#
#         AccountsReceivable  AccumulatedDepreciation  \
# symbol
# aapl          2.292600e+10            -5.857900e+10
# aapl          1.612000e+10            -6.676000e+10
# aapl          2.627800e+10            -7.028300e+10
# aapl          2.818400e+10            -7.234000e+10
#
#         AvailableForSaleSecurities  CapitalStock  CashAndCashEquivalents  \
# symbol
# aapl                  1.053410e+11  4.517400e+10            4.884400e+10
# aapl                  1.008870e+11  5.077900e+10            3.801600e+10
# aapl                  1.278770e+11  5.736500e+10            3.494000e+10
# aapl                  1.208050e+11  6.484900e+10            2.364600e+10
#
# ...

# %%
aapl.balance_sheet(trailing=False)
# Out:
#          asOfDate periodType currencyCode  AccountsPayable  \
# symbol
# aapl   2019-09-30        12M          USD     4.623600e+10
# aapl   2020-09-30        12M          USD     4.229600e+10
# aapl   2021-09-30        12M          USD     5.476300e+10
# aapl   2022-09-30        12M          USD     6.411500e+10
#
#         AccountsReceivable  AccumulatedDepreciation  \
# symbol
# aapl          2.292600e+10            -5.857900e+10
# aapl          1.612000e+10            -6.676000e+10
# aapl          2.627800e+10            -7.028300e+10
# aapl          2.818400e+10            -7.234000e+10
#
#         AvailableForSaleSecurities  CapitalStock  CashAndCashEquivalents  \
# symbol
# aapl                  1.053410e+11  4.517400e+10            4.884400e+10
# aapl                  1.008870e+11  5.077900e+10            3.801600e+10
# aapl                  1.278770e+11  5.736500e+10            3.494000e+10
# aapl                  1.208050e+11  6.484900e+10            2.364600e+10
#
# ...

# %%
aapl.balance_sheet(trailing=True)
# Out:
#          asOfDate periodType currencyCode  AccountsPayable  \
# symbol
# aapl   2019-09-30        12M          USD     4.623600e+10
# aapl   2020-09-30        12M          USD     4.229600e+10
# aapl   2021-09-30        12M          USD     5.476300e+10
# aapl   2022-09-30        12M          USD     6.411500e+10
#
#         AccountsReceivable  AccumulatedDepreciation  \
# symbol
# aapl          2.292600e+10            -5.857900e+10
# aapl          1.612000e+10            -6.676000e+10
# aapl          2.627800e+10            -7.028300e+10
# aapl          2.818400e+10            -7.234000e+10
#
#         AvailableForSaleSecurities  CapitalStock  CashAndCashEquivalents  \
# symbol
# aapl                  1.053410e+11  4.517400e+10            4.884400e+10
# aapl                  1.008870e+11  5.077900e+10            3.801600e+10
# aapl                  1.278770e+11  5.736500e+10            3.494000e+10
# aapl                  1.208050e+11  6.484900e+10            2.364600e+10
#
# ...
